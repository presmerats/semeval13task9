# %%
from FeatureExtraction import FeatureExtraction
import os

#os.chdir(os.path.dirname(sys.argv[0]))
print(os.getcwd())
fe =FeatureExtraction("../data/LaboCase/Train")
fe.load()
fe.extractFeatures(30)
fe.printerrors()  
fe.printdata()
# Out:
# /media/disk/home/pau/Projectes/AHLT-mai/src
# ['__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_predicate', 'append', 'assign', 'back', 'begin', 'clear', 'empty', 'end', 'erase', 'front', 'get_allocator', 'get_best_seq', 'get_dep_tree', 'get_parse_tree', 'get_predicate_by_number', 'get_predicate_by_pos', 'get_predicate_number', 'get_predicate_position', 'get_predicates', 'get_sentence_id', 'get_word_iterator', 'get_words', 'insert', 'is_dep_parsed', 'is_parsed', 'is_predicate', 'is_tagged', 'iterator', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rebuild_word_index', 'rend', 'resize', 'reverse', 'set_best_seq', 'set_dep_tree', 'set_is_tagged', 'set_parse_tree', 'set_sentence_id', 'size', 'swap', 'this', 'words_begin', 'words_end']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ...
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ['AFFIXES', 'COMPOUNDS', 'DATES', 'DICTIONARY', 'GUESSER', 'MULTIWORDS', 'NER', 'NUMBERS', 'PROBABILITIES', 'PUNCTUATION', 'QUANTITIES', 'USERMAP', '__bool__', '__class__', '__del__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'add_alternative', 'add_analysis', 'alternatives_begin', 'alternatives_end', 'analysis_begin', 'analysis_end', 'append', 'assign', 'back', 'begin', 'clear', 'clear_alternatives', 'copy_analysis', 'empty', 'end', 'erase', 'find_tag_match', 'front', 'get_allocator', 'get_alternatives', 'get_analysis', 'get_analyzed_by', 'get_form', 'get_lc_form', 'get_lemma', 'get_n_analysis', 'get_n_selected', 'get_n_unselected', 'get_n_words_mw', 'get_ph_form', 'get_position', 'get_senses', 'get_senses_string', 'get_span_finish', 'get_span_start', 'get_tag', 'get_words_mw', 'has_alternatives', 'has_retokenizable', 'insert', 'is_ambiguous_mw', 'is_analyzed_by', 'is_locked_analysis', 'is_locked_multiwords', 'is_multiword', 'iterator', 'lock_analysis', 'lock_multiwords', 'num_kbest', 'pop', 'pop_back', 'pop_front', 'push_back', 'push_front', 'rbegin', 'rend', 'resize', 'reverse', 'select_all_analysis', 'select_analysis', 'selected_begin', 'selected_end', 'set_alternatives', 'set_ambiguous_mw', 'set_analysis', 'set_analyzed_by', 'set_form', 'set_ph_form', 'set_position', 'set_senses', 'set_span', 'size', 'swap', 'this', 'unlock_analysis', 'unlock_multiwords', 'unselect_all_analysis', 'unselect_analysis', 'unselected_begin', 'unselected_end', 'user']
# 32
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# 256
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-0f0ed7969afb> in <module>()
#       6 fe =FeatureExtraction("../data/LaboCase/Train")
#       7 fe.load()
# ----> 8 fe.extractFeatures(30)
#       9 fe.printerrors()
#      10 fe.printdata()
#
# /media/disk/home/pau/Projectes/AHLT-mai/src/FeatureExtraction.py in extractFeatures(self, limit, mode)
#     158
#     159             # Chunking (nltk)
# --> 160             self.chunker.chunkElement(element)
#     161
#     162             # BIO tag
#
# /media/disk/home/pau/Projectes/AHLT-mai/src/ChunkFeatures.py in chunkElement(self, element)
#      12         # perform chunking
#      13         if len(sent)>0:
# ---> 14             chunklist = nltk.ne_chunk(sent, binary=True)
#      15
#      16         # what to save?
#
# ~/anaconda3/envs/ahltmai/lib/python3.6/site-packages/nltk/chunk/__init__.py in ne_chunk(tagged_tokens, binary)
#     175         chunker_pickle = _MULTICLASS_NE_CHUNKER
#     176     chunker = load(chunker_pickle)
# --> 177     return chunker.parse(tagged_tokens)
#     178
#     179 def ne_chunk_sents(tagged_sentences, binary=False):
#
# ~/anaconda3/envs/ahltmai/lib/python3.6/site-packages/nltk/chunk/named_entity.py in parse(self, tokens)
#     120         Each token should be a pos-tagged word
#     121         """
# --> 122         tagged = self._tagger.tag(tokens)
#     123         tree = self._tagged_to_parse(tagged)
#     124         return tree
#
# ~/anaconda3/envs/ahltmai/lib/python3.6/site-packages/nltk/tag/sequential.py in tag(self, tokens)
#      61         tags = []
#      62         for i in range(len(tokens)):
# ---> 63             tags.append(self.tag_one(tokens, i, tags))
#      64         return list(zip(tokens, tags))
#      65
#
# ~/anaconda3/envs/ahltmai/lib/python3.6/site-packages/nltk/tag/sequential.py in tag_one(self, tokens, index, history)
#      81         tag = None
#      82         for tagger in self._taggers:
# ---> 83             tag = tagger.choose_tag(tokens, index, history)
#      84             if tag is not None:
#      85                 break
#
# ~/anaconda3/envs/ahltmai/lib/python3.6/site-packages/nltk/tag/sequential.py in choose_tag(self, tokens, index, history)
#     630     def choose_tag(self, tokens, index, history):
#     631         # Use our feature detector to get the featureset.
# --> 632         featureset = self.feature_detector(tokens, index, history)
#     633
#     634         # Use the classifier to pick a tag.  If a cutoff probability
#
# ~/anaconda3/envs/ahltmai/lib/python3.6/site-packages/nltk/tag/sequential.py in feature_detector(self, tokens, index, history)
#     678         See ``classifier()``
#     679         """
# --> 680         return self._feature_detector(tokens, index, history)
#     681
#     682     def classifier(self):
#
# ~/anaconda3/envs/ahltmai/lib/python3.6/site-packages/nltk/chunk/named_entity.py in _feature_detector(self, tokens, index, history)
#      53     def _feature_detector(self, tokens, index, history):
#      54         word = tokens[index][0]
# ---> 55         pos = simplify_pos(tokens[index][1])
#      56         if index == 0:
#      57             prevword = prevprevword = None
#
# IndexError: string index out of range

# %%
import nltk
sent = "this is a sentence ok?" # not ready for the nltk ne_chunk
sent = nltk.corpus.treebank.tagged_sents()[22]
print(sent)
print(nltk.ne_chunk(sent))
# Out:
# [('The', 'DT'), ('U.S.', 'NNP'), ('is', 'VBZ'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('few', 'JJ'), ('industrialized', 'VBN'), ('nations', 'NNS'), ('that', 'WDT'), ('*T*-7', '-NONE-'), ('does', 'VBZ'), ("n't", 'RB'), ('have', 'VB'), ('a', 'DT'), ('higher', 'JJR'), ('standard', 'NN'), ('of', 'IN'), ('regulation', 'NN'), ('for', 'IN'), ('the', 'DT'), ('smooth', 'JJ'), (',', ','), ('needle-like', 'JJ'), ('fibers', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('crocidolite', 'NN'), ('that', 'WDT'), ('*T*-1', '-NONE-'), ('are', 'VBP'), ('classified', 'VBN'), ('*-5', '-NONE-'), ('as', 'IN'), ('amphobiles', 'NNS'), (',', ','), ('according', 'VBG'), ('to', 'TO'), ('Brooke', 'NNP'), ('T.', 'NNP'), ('Mossman', 'NNP'), (',', ','), ('a', 'DT'), ('professor', 'NN'), ('of', 'IN'), ('pathlogy', 'NN'), ('at', 'IN'), ('the', 'DT'), ('University', 'NNP'), ('of', 'IN'), ('Vermont', 'NNP'), ('College', 'NNP'), ('of', 'IN'), ('Medicine', 'NNP'), ('.', '.')]
# (S
#   The/DT
#   (GPE U.S./NNP)
#   is/VBZ
#   one/CD
#   of/IN
#   the/DT
#   few/JJ
#   industrialized/VBN
#   nations/NNS
#   that/WDT
#   *T*-7/-NONE-
#   does/VBZ
#   n't/RB
#   have/VB
#   a/DT
#   higher/JJR
#   standard/NN
#   of/IN
#   regulation/NN
#   for/IN
#   the/DT
#   smooth/JJ
#   ,/,
#   needle-like/JJ
#   fibers/NNS
#   such/JJ
#   as/IN
#   crocidolite/NN
#   that/WDT
#   *T*-1/-NONE-
#   are/VBP
#   classified/VBN
#   *-5/-NONE-
#   as/IN
#   amphobiles/NNS
#   ,/,
#   according/VBG
#   to/TO
#   (PERSON Brooke/NNP T./NNP Mossman/NNP)
#   ,/,
#   a/DT
#   professor/NN
#   of/IN
#   pathlogy/NN
#   at/IN
#   the/DT
#   (ORGANIZATION University/NNP)
#   of/IN
#   (PERSON Vermont/NNP College/NNP)
#   of/IN
#   (GPE Medicine/NNP)
#   ./.)

# %%
fe.save('../data/models/data-test.json')

# %%
import SVMtrainer
vectorizeddata = SVMtrainer.dataFormatting(datafile='../data/models/data-test.json')
SVMtrainer.saveVectorizedData(vectorizeddata,'../data/models/data-test.pkl')
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 7159
# True

# %%
vdata=SVMtrainer.loadVectorizedData('../data/models/data-test.pkl')
vdata[1]
# Out:
# <7159x23573 sparse matrix of type '<class 'numpy.float64'>'
# 	with 201940 stored elements in Compressed Sparse Row format>

# %%
clf = SVMtrainer.trainSVM(vdata)
SVMtrainer.saveModel(clf,'../data/models/svm-20180509.pkl')
# Out:
#              precision    recall  f1-score   support
#
#           B       0.00      0.00      0.00       465
#           I       0.00      0.00      0.00       121
#           O       0.92      1.00      0.96      6573
#
# avg / total       0.84      0.92      0.88      7159
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# input test files folder  and prepare for prediction

# %%
clf2 = SVMTrainer.loadModel('../data/models/svm-20180509.pkl')
# prepare some test set with the data preparation routines
clf2.predict(X[0:1])
