# %%
import lxml
import os, sys
from xml.dom.minidom import parse, parseString
import xmltodict
from bs4 import BeautifulSoup
import pprint
import nltk
import re
import copy
import pickle
import json




class DrugBankLookup():
    """

    """
    data = []
    files_path = ""
    
    
    def __init__(self, path, pickled=False):
        self.files_path = path
        self.data = {}
            
        if pickled:
            self.loadPickle(path)
            
    def save(self,path="lookupdict"):
        with open(path + '.pkl', 'wb') as output:
            pickle.dump(self.data, output)
            
    def loadPickle(self,path):
        with open(path, 'rb') as output:
            self.data = pickle.load(output)
       
    def load(self):
        """
            walks recursively the file system beginning at self.files_path
            then parses each file tino the corresponding elem in the datastruct
        """
        #os.chdir(self.files_path)
        for root, dirs, files in os.walk(self.files_path, topdown = False):
            for name in files:
                if os.path.basename(name).endswith(".xml"):
                    self.parseXml(os.path.join(root, name))
                    #print(name)
                    #self.parseXmlfast(os.path.join(root, name))
                    

    def parseXmlfast(self,filepath):
        """
            Parses one single xml file, saving data to the self.data datastruct
            as a dictionary image of the original xml
        """
        with open(filepath, 'r') as f:
            #parse
            doc = xmltodict.parse(f.read())
            self.data.update(doc)
        
    def parseXml(self,filepath):
        """
            Parses one single xml file, saving data to the self.data datastruct
            as a list of names and synonyms (nothing else is saved!)
        """
        with open(filepath, 'r') as f:
            #parse
            doc = xmltodict.parse(f.read())
            
            newlist = []

            d2 = doc['drugbank']
            d3 = d2['drug']
            for element in d3:
                newlist.append(element['name'].lower())
                try:
                    synonyms  = element['synonyms']
                    if synonyms:
                        for k,v in synonyms.items():
                            for elem in v:
                                newlist.append(elem['#text'].lower())
                                
                except:
                    pass

        self.data = newlist

            
    def lookup(self,word):
        """
            
        """
        return word in self.data
       
        
        
        
if __name__ == '__main__':

    fe =DrugBankLookup("../data/Dictionaries/")
    fe.load()
    fe.lookup('paracetamol')
    fe.lookup('overfit')
    fe.save("../data/Dictionaries/drugbank")

# %%
fe.lookup('hola')
print(fe.lookup('overfit'))
print(fe.lookup('paracetaml'))
print(len(fe.data))
print(fe.data[:3])
# Out:
# False
# False
# 27022
# ['Lepirudin', 'Hirudin variant-1', 'Lepirudin recombinant']

# %%
fe2 =DrugBankLookup("../data/Dictionaries/drugbank.pkl", pickled=True)
print(fe2.data)
fe2.lookup('paracetamol')
fe2.lookup('paracetaml')
# Out:
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-8ba7a6ba0635> in <module>()
#       1 fe2 =DrugBankLookup("../data/Dictionaries/drugbank.pkl", pickled=True)
#       2 print(fe2.data)
# ----> 3 fe2.lookup('paracetamol')
#       4 fe2.lookup('paracetaml')
#
# <ipython-input-4-5c6d7a2b166e> in lookup(self, word)
#      93
#      94         """
# ---> 95         return word in self.data
#      96
#      97
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
print(fe.data.keys())
print(type(fe.data['drugbank']))
d2 = fe.data['drugbank']
#print('paracetaml' in d2.keys())
#print('paracetamol' in d2.keys())
#print(d2.keys())
d3 = d2['drug']
#print(type(d3))
#print(len(d3))
#print(d3[:3])
#print('paracetamol' in [e.])
for element in d3:
    print(type(element))
    #print(element.keys())
    
    print("name:",element['name'])
    try:
        synonyms  = element['synonyms']
        
        if synonyms:
            
            print("type synonyms:",type(synonyms))
            print("synonym keys",synonyms.keys())
            for k,v in synonyms.items():
                print("syn key",k)
                print(len(v))
                for elem in v:
                    print(elem['#text'])
                    
                
                
            #for syn in synonyms:
            #    print("type",type(syn))
            #    print(syn)
    except:
        pass
    print()
    print()
# Out:
# dict_keys(['drugbank'])
# <class 'collections.OrderedDict'>
# <class 'collections.OrderedDict'>
# name: Lepirudin
# type synonyms: <class 'collections.OrderedDict'>
# synonym keys odict_keys(['synonym'])
# syn key synonym
# 2
# Hirudin variant-1
# Lepirudin recombinant
#
#
# <class 'collections.OrderedDict'>
# name: Cetuximab
# type synonyms: <class 'collections.OrderedDict'>
# synonym keys odict_keys(['synonym'])
# syn key synonym
# 4
# Cetuximab
# Cétuximab
# Cetuximabum
# Immunoglobulin G 1 (human-mouse monoclonal C 225 gamma 1 - chain anti-human epidermal growt factor receptor), disulfide wit human-mouse monoclonal C 225 kappa - chain, dimer
#
#
# <class 'collections.OrderedDict'>
# name: Dornase alfa
# type synonyms: <class 'collections.OrderedDict'>
# synonym keys odict_keys(['synonym'])
# syn key synonym
# 4
# Deoxyribonuclease (human clone 18-1 protein moiety)
# Dornase alfa, recombinant
# Dornase alpha
# Recombinant deoxyribonuclease (DNAse)
#
#
# ...
