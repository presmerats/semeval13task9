# %%
from FeatureExtraction import FeatureExtraction
import os

#os.chdir(os.path.dirname(sys.argv[0]))
print(os.getcwd())
fe =FeatureExtraction("../data/LaboCase/Train")
fe.load()
fe.extractFeatures(300)
fe.printerrors()  
fe.printdata()
# Out:
# /media/disk/home/pau/Projectes/AHLT-mai/src
# biotag errors count:
# 35
# token offset errors count:
# 0
# [{'Error': False,
#   'bioerrors': 0,
#   'entities': [{'charOffset': '50-67',
#                 'id': 'DDI-MedLine.d134.s0.e0',
#                 'text': 'radiopertechnetate',
#                 'type': 'drug'},
#                {'charOffset': '72-89',
#                 'id': 'DDI-MedLine.d134.s0.e1',
#                 'text': 'sodium perchlorate',
#                 'type': 'drug_n'},
#                {'charOffset': '169-186',
#                 'id': 'DDI-MedLine.d134.s0.e2',
#                 'text': 'sodium perchlorate',
#                 'type': 'drug_n'},
#                {'charOffset': '266-283',
#                 'id': 'DDI-MedLine.d134.s0.e3',
#                 'text': 'radiopertechnetate',
#                 'type': 'drug'}],
#   'errors': [],
#   'features': [('[',
#                 '[',
#                 'Fca',
#                 0,
#                 0,
#                 1,
#                 'O',
#                 False,
#                 False,
#                 False,
#                 False,
#                 True,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 1,
#                 '',
#                 '',
#                 '',
#                 'NN',
#                 'dose-time',
#                 'Dose-time',
#                 '',
#                 '',
#                 '',
#                 'NNS',
#                 'effect',
#                 'effects',
#                 '',
#                 '',
#                 '',
#                 'IN',
#                 'of',
#                 'of'),
#                ('Dose-time',
#                 'dose-time',
#                 'NN',
#                 1,
#                 1,
#                 10,
#                 'O',
#                 True,
#                 False,
#                 False,
#                 False,
#                 True,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 9,
#                 'Fca',
#                 '[',
#                 '[',
#                 'NNS',
#                 'effect',
#                 'effects',
#                 '',
#                 '',
#                 '',
#                 'IN',
#                 'of',
#                 'of',
#                 '',
#                 '',
#                 '',
#                 'JJ',
#                 'competitive',
#                 'competitive'),
#                ('effects',
#                 'effect',
#                 'NNS',
#                 2,
#                 11,
#                 18,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 's',
#                 0,
#                 1,
#                 7,
#                 'NN',
#                 'dose-time',
#                 'Dose-time',
#                 'IN',
#                 'of',
#                 'of',
#                 'Fca',
#                 '[',
#                 '[',
#                 'JJ',
#                 'competitive',
#                 'competitive',
#                 '',
#                 '',
#                 '',
#                 'NN',
#                 'displacement',
#                 'displacement'),
#                ('of',
#                 'of',
#                 'IN',
#                 3,
#                 19,
#                 21,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NNS',
#                 'effect',
#                 'effects',
#                 'JJ',
#                 'competitive',
#                 'competitive',
#                 'NN',
#                 'dose-time',
#                 'Dose-time',
#                 'NN',
#                 'displacement',
#                 'displacement',
#                 'Fca',
#                 '[',
#                 '[',
#                 'IN',
#                 'of',
#                 'of'),
#                ('competitive',
#                 'competitive',
#                 'JJ',
#                 4,
#                 22,
#                 33,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 True,
#                 '',
#                 '',
#                 0,
#                 0,
#                 11,
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'displacement',
#                 'displacement',
#                 'NNS',
#                 'effect',
#                 'effects',
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'dose-time',
#                 'Dose-time',
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate'),
#                ('displacement',
#                 'displacement',
#                 'NN',
#                 5,
#                 34,
#                 46,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 True,
#                 '',
#                 '',
#                 0,
#                 0,
#                 12,
#                 'JJ',
#                 'competitive',
#                 'competitive',
#                 'IN',
#                 'of',
#                 'of',
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate',
#                 'NNS',
#                 'effect',
#                 'effects',
#                 'IN',
#                 'by',
#                 'by'),
#                ('of',
#                 'of',
#                 'IN',
#                 6,
#                 47,
#                 49,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NN',
#                 'displacement',
#                 'displacement',
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate',
#                 'JJ',
#                 'competitive',
#                 'competitive',
#                 'IN',
#                 'by',
#                 'by',
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'sodium',
#                 'sodium'),
#                ('radiopertechnetate',
#                 'radiopertechnetate',
#                 'NN',
#                 7,
#                 50,
#                 68,
#                 'B',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 True,
#                 '',
#                 '',
#                 0,
#                 0,
#                 18,
#                 'IN',
#                 'of',
#                 'of',
#                 'IN',
#                 'by',
#                 'by',
#                 'NN',
#                 'displacement',
#                 'displacement',
#                 'NN',
#                 'sodium',
#                 'sodium',
#                 'JJ',
#                 'competitive',
#                 'competitive',
#                 'NN',
#                 'perchlorate',
#                 'perchlorate'),
#                ('by',
#                 'by',
#                 'IN',
#                 8,
#                 69,
#                 71,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate',
#                 'NN',
#                 'sodium',
#                 'sodium',
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'perchlorate',
#                 'perchlorate',
#                 'NN',
#                 'displacement',
#                 'displacement',
#                 'VBG',
#                 'follow',
#                 'following'),
#                ('sodium',
#                 'sodium',
#                 'NN',
#                 9,
#                 72,
#                 78,
#                 'B',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 6,
#                 'IN',
#                 'by',
#                 'by',
#                 'NN',
#                 'perchlorate',
#                 'perchlorate',
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate',
#                 'VBG',
#                 'follow',
#                 'following',
#                 'IN',
#                 'of',
#                 'of',
#                 'JJ',
#                 'oral',
#                 'oral'),
#                ('perchlorate',
#                 'perchlorate',
#                 'NN',
#                 10,
#                 79,
#                 90,
#                 'I',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 True,
#                 '',
#                 '',
#                 0,
#                 0,
#                 11,
#                 'NN',
#                 'sodium',
#                 'sodium',
#                 'VBG',
#                 'follow',
#                 'following',
#                 'IN',
#                 'by',
#                 'by',
#                 'JJ',
#                 'oral',
#                 'oral',
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate',
#                 'CC',
#                 'and',
#                 'and'),
#                ('following',
#                 'follow',
#                 'VBG',
#                 11,
#                 91,
#                 100,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 'ing',
#                 0,
#                 3,
#                 9,
#                 'NN',
#                 'perchlorate',
#                 'perchlorate',
#                 'JJ',
#                 'oral',
#                 'oral',
#                 'NN',
#                 'sodium',
#                 'sodium',
#                 'CC',
#                 'and',
#                 'and',
#                 'IN',
#                 'by',
#                 'by',
#                 'JJ',
#                 'intravenous',
#                 'intravenous'),
#                ('oral',
#                 'oral',
#                 'JJ',
#                 12,
#                 101,
#                 105,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 4,
#                 'VBG',
#                 'follow',
#                 'following',
#                 'CC',
#                 'and',
#                 'and',
#                 'NN',
#                 'perchlorate',
#                 'perchlorate',
#                 'JJ',
#                 'intravenous',
#                 'intravenous',
#                 'NN',
#                 'sodium',
#                 'sodium',
#                 'NN',
#                 'administration',
#                 'administration'),
#                ('and',
#                 'and',
#                 'CC',
#                 13,
#                 106,
#                 109,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 3,
#                 'JJ',
#                 'oral',
#                 'oral',
#                 'JJ',
#                 'intravenous',
#                 'intravenous',
#                 'VBG',
#                 'follow',
#                 'following',
#                 'NN',
#                 'administration',
#                 'administration',
#                 'NN',
#                 'perchlorate',
#                 'perchlorate',
#                 'Fct',
#                 ']',
#                 ']'),
#                ('intravenous',
#                 'intravenous',
#                 'JJ',
#                 14,
#                 110,
#                 121,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 True,
#                 '',
#                 '',
#                 0,
#                 0,
#                 11,
#                 'CC',
#                 'and',
#                 'and',
#                 'NN',
#                 'administration',
#                 'administration',
#                 'JJ',
#                 'oral',
#                 'oral',
#                 'Fct',
#                 ']',
#                 ']',
#                 'VBG',
#                 'follow',
#                 'following',
#                 'DT',
#                 'the',
#                 'The'),
#                ('administration',
#                 'administration',
#                 'NN',
#                 15,
#                 122,
#                 136,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 True,
#                 '',
#                 '',
#                 0,
#                 0,
#                 14,
#                 'JJ',
#                 'intravenous',
#                 'intravenous',
#                 'Fct',
#                 ']',
#                 ']',
#                 'CC',
#                 'and',
#                 'and',
#                 'DT',
#                 'the',
#                 'The',
#                 'JJ',
#                 'oral',
#                 'oral',
#                 'NN',
#                 'effect',
#                 'effect'),
#                (']',
#                 ']',
#                 'Fct',
#                 16,
#                 136,
#                 137,
#                 'O',
#                 False,
#                 False,
#                 False,
#                 False,
#                 True,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 1,
#                 'NN',
#                 'administration',
#                 'administration',
#                 'DT',
#                 'the',
#                 'The',
#                 'JJ',
#                 'intravenous',
#                 'intravenous',
#                 'NN',
#                 'effect',
#                 'effect',
#                 'CC',
#                 'and',
#                 'and',
#                 'IN',
#                 'of',
#                 'of'),
#                ('The',
#                 'the',
#                 'DT',
#                 17,
#                 138,
#                 141,
#                 'O',
#                 True,
#                 False,
#                 False,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 3,
#                 'Fct',
#                 ']',
#                 ']',
#                 'NN',
#                 'effect',
#                 'effect',
#                 'NN',
#                 'administration',
#                 'administration',
#                 'IN',
#                 'of',
#                 'of',
#                 'JJ',
#                 'intravenous',
#                 'intravenous',
#                 'JJ',
#                 'various',
#                 'various'),
#                ('effect',
#                 'effect',
#                 'NN',
#                 18,
#                 142,
#                 148,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 6,
#                 'DT',
#                 'the',
#                 'The',
#                 'IN',
#                 'of',
#                 'of',
#                 'Fct',
#                 ']',
#                 ']',
#                 'JJ',
#                 'various',
#                 'various',
#                 'NN',
#                 'administration',
#                 'administration',
#                 'NNS',
#                 'dose',
#                 'doses'),
#                ('of',
#                 'of',
#                 'IN',
#                 19,
#                 149,
#                 151,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NN',
#                 'effect',
#                 'effect',
#                 'JJ',
#                 'various',
#                 'various',
#                 'DT',
#                 'the',
#                 'The',
#                 'NNS',
#                 'dose',
#                 'doses',
#                 'Fct',
#                 ']',
#                 ']',
#                 'IN',
#                 'of',
#                 'of'),
#                ('various',
#                 'various',
#                 'JJ',
#                 20,
#                 152,
#                 159,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 7,
#                 'IN',
#                 'of',
#                 'of',
#                 'NNS',
#                 'dose',
#                 'doses',
#                 'NN',
#                 'effect',
#                 'effect',
#                 'IN',
#                 'of',
#                 'of',
#                 'DT',
#                 'the',
#                 'The',
#                 'NN',
#                 'sodium',
#                 'sodium'),
#                ('doses',
#                 'dose',
#                 'NNS',
#                 21,
#                 160,
#                 165,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 's',
#                 0,
#                 1,
#                 5,
#                 'JJ',
#                 'various',
#                 'various',
#                 'IN',
#                 'of',
#                 'of',
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'sodium',
#                 'sodium',
#                 'NN',
#                 'effect',
#                 'effect',
#                 'NN',
#                 'perchlorate',
#                 'perchlorate'),
#                ('of',
#                 'of',
#                 'IN',
#                 22,
#                 166,
#                 168,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NNS',
#                 'dose',
#                 'doses',
#                 'NN',
#                 'sodium',
#                 'sodium',
#                 'JJ',
#                 'various',
#                 'various',
#                 'NN',
#                 'perchlorate',
#                 'perchlorate',
#                 'IN',
#                 'of',
#                 'of',
#                 'IN',
#                 'in',
#                 'in'),
#                ('sodium',
#                 'sodium',
#                 'NN',
#                 23,
#                 169,
#                 175,
#                 'B',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 6,
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'perchlorate',
#                 'perchlorate',
#                 'NNS',
#                 'dose',
#                 'doses',
#                 'IN',
#                 'in',
#                 'in',
#                 'JJ',
#                 'various',
#                 'various',
#                 'DT',
#                 'several',
#                 'several'),
#                ('perchlorate',
#                 'perchlorate',
#                 'NN',
#                 24,
#                 176,
#                 187,
#                 'I',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 True,
#                 '',
#                 '',
#                 0,
#                 0,
#                 11,
#                 'NN',
#                 'sodium',
#                 'sodium',
#                 'IN',
#                 'in',
#                 'in',
#                 'IN',
#                 'of',
#                 'of',
#                 'DT',
#                 'several',
#                 'several',
#                 'NNS',
#                 'dose',
#                 'doses',
#                 'NN',
#                 'dose',
#                 'dose'),
#                ('in',
#                 'in',
#                 'IN',
#                 25,
#                 188,
#                 190,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NN',
#                 'perchlorate',
#                 'perchlorate',
#                 'DT',
#                 'several',
#                 'several',
#                 'NN',
#                 'sodium',
#                 'sodium',
#                 'NN',
#                 'dose',
#                 'dose',
#                 'IN',
#                 'of',
#                 'of',
#                 'NNS',
#                 'fraction',
#                 'fractions'),
#                ('several',
#                 'several',
#                 'DT',
#                 26,
#                 191,
#                 198,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 7,
#                 'IN',
#                 'in',
#                 'in',
#                 'NN',
#                 'dose',
#                 'dose',
#                 'NN',
#                 'perchlorate',
#                 'perchlorate',
#                 'NNS',
#                 'fraction',
#                 'fractions',
#                 'NN',
#                 'sodium',
#                 'sodium',
#                 'IN',
#                 'on',
#                 'on'),
#                ('dose',
#                 'dose',
#                 'NN',
#                 27,
#                 199,
#                 203,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 4,
#                 'DT',
#                 'several',
#                 'several',
#                 'NNS',
#                 'fraction',
#                 'fractions',
#                 'IN',
#                 'in',
#                 'in',
#                 'IN',
#                 'on',
#                 'on',
#                 'NN',
#                 'perchlorate',
#                 'perchlorate',
#                 'DT',
#                 'the',
#                 'the'),
#                ('fractions',
#                 'fraction',
#                 'NNS',
#                 28,
#                 204,
#                 213,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 's',
#                 0,
#                 1,
#                 9,
#                 'NN',
#                 'dose',
#                 'dose',
#                 'IN',
#                 'on',
#                 'on',
#                 'DT',
#                 'several',
#                 'several',
#                 'DT',
#                 'the',
#                 'the',
#                 'IN',
#                 'in',
#                 'in',
#                 'NN',
#                 'extent',
#                 'extent'),
#                ('on',
#                 'on',
#                 'IN',
#                 29,
#                 214,
#                 216,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NNS',
#                 'fraction',
#                 'fractions',
#                 'DT',
#                 'the',
#                 'the',
#                 'NN',
#                 'dose',
#                 'dose',
#                 'NN',
#                 'extent',
#                 'extent',
#                 'DT',
#                 'several',
#                 'several',
#                 'CC',
#                 'and',
#                 'and'),
#                ('the',
#                 'the',
#                 'DT',
#                 30,
#                 217,
#                 220,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 3,
#                 'IN',
#                 'on',
#                 'on',
#                 'NN',
#                 'extent',
#                 'extent',
#                 'NNS',
#                 'fraction',
#                 'fractions',
#                 'CC',
#                 'and',
#                 'and',
#                 'NN',
#                 'dose',
#                 'dose',
#                 'DT',
#                 'the',
#                 'the'),
#                ('extent',
#                 'extent',
#                 'NN',
#                 31,
#                 221,
#                 227,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 6,
#                 'DT',
#                 'the',
#                 'the',
#                 'CC',
#                 'and',
#                 'and',
#                 'IN',
#                 'on',
#                 'on',
#                 'DT',
#                 'the',
#                 'the',
#                 'NNS',
#                 'fraction',
#                 'fractions',
#                 'NN',
#                 'time',
#                 'time'),
#                ('and',
#                 'and',
#                 'CC',
#                 32,
#                 228,
#                 231,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 3,
#                 'NN',
#                 'extent',
#                 'extent',
#                 'DT',
#                 'the',
#                 'the',
#                 'DT',
#                 'the',
#                 'the',
#                 'NN',
#                 'time',
#                 'time',
#                 'IN',
#                 'on',
#                 'on',
#                 'NN',
#                 'scale',
#                 'scale'),
#                ('the',
#                 'the',
#                 'DT',
#                 33,
#                 232,
#                 235,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 3,
#                 'CC',
#                 'and',
#                 'and',
#                 'NN',
#                 'time',
#                 'time',
#                 'NN',
#                 'extent',
#                 'extent',
#                 'NN',
#                 'scale',
#                 'scale',
#                 'DT',
#                 'the',
#                 'the',
#                 'IN',
#                 'of',
#                 'of'),
#                ('time',
#                 'time',
#                 'NN',
#                 34,
#                 236,
#                 240,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 4,
#                 'DT',
#                 'the',
#                 'the',
#                 'NN',
#                 'scale',
#                 'scale',
#                 'CC',
#                 'and',
#                 'and',
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'extent',
#                 'extent',
#                 'NN',
#                 'displacement',
#                 'displacement'),
#                ('scale',
#                 'scale',
#                 'NN',
#                 35,
#                 241,
#                 246,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 5,
#                 'NN',
#                 'time',
#                 'time',
#                 'IN',
#                 'of',
#                 'of',
#                 'DT',
#                 'the',
#                 'the',
#                 'NN',
#                 'displacement',
#                 'displacement',
#                 'CC',
#                 'and',
#                 'and',
#                 'IN',
#                 'of',
#                 'of'),
#                ('of',
#                 'of',
#                 'IN',
#                 36,
#                 247,
#                 249,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NN',
#                 'scale',
#                 'scale',
#                 'NN',
#                 'displacement',
#                 'displacement',
#                 'NN',
#                 'time',
#                 'time',
#                 'IN',
#                 'of',
#                 'of',
#                 'DT',
#                 'the',
#                 'the',
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate'),
#                ('displacement',
#                 'displacement',
#                 'NN',
#                 37,
#                 250,
#                 262,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 True,
#                 '',
#                 '',
#                 0,
#                 0,
#                 12,
#                 'IN',
#                 'of',
#                 'of',
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'scale',
#                 'scale',
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate',
#                 'NN',
#                 'time',
#                 'time',
#                 'Fc',
#                 ',',
#                 ','),
#                ('of',
#                 'of',
#                 'IN',
#                 38,
#                 263,
#                 265,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NN',
#                 'displacement',
#                 'displacement',
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate',
#                 'IN',
#                 'of',
#                 'of',
#                 'Fc',
#                 ',',
#                 ',',
#                 'NN',
#                 'scale',
#                 'scale',
#                 'IN',
#                 'in',
#                 'in'),
#                ('radiopertechnetate',
#                 'radiopertechnetate',
#                 'NN',
#                 39,
#                 266,
#                 284,
#                 'B',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 True,
#                 '',
#                 '',
#                 0,
#                 0,
#                 18,
#                 'IN',
#                 'of',
#                 'of',
#                 'Fc',
#                 ',',
#                 ',',
#                 'NN',
#                 'displacement',
#                 'displacement',
#                 'IN',
#                 'in',
#                 'in',
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'dependence',
#                 'dependence'),
#                (',',
#                 ',',
#                 'Fc',
#                 40,
#                 284,
#                 285,
#                 'O',
#                 False,
#                 False,
#                 False,
#                 False,
#                 True,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 1,
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate',
#                 'IN',
#                 'in',
#                 'in',
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'dependence',
#                 'dependence',
#                 'NN',
#                 'displacement',
#                 'displacement',
#                 'IN',
#                 'on',
#                 'on'),
#                ('in',
#                 'in',
#                 'IN',
#                 41,
#                 286,
#                 288,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'Fc',
#                 ',',
#                 ',',
#                 'NN',
#                 'dependence',
#                 'dependence',
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate',
#                 'IN',
#                 'on',
#                 'on',
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'application',
#                 'application'),
#                ('dependence',
#                 'dependence',
#                 'NN',
#                 42,
#                 289,
#                 299,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 10,
#                 'IN',
#                 'in',
#                 'in',
#                 'IN',
#                 'on',
#                 'on',
#                 'Fc',
#                 ',',
#                 ',',
#                 'NN',
#                 'application',
#                 'application',
#                 'NN',
#                 'radiopertechnetate',
#                 'radiopertechnetate',
#                 'NN',
#                 'mode',
#                 'mode'),
#                ('on',
#                 'on',
#                 'IN',
#                 43,
#                 300,
#                 302,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NN',
#                 'dependence',
#                 'dependence',
#                 'NN',
#                 'application',
#                 'application',
#                 'IN',
#                 'in',
#                 'in',
#                 'NN',
#                 'mode',
#                 'mode',
#                 'Fc',
#                 ',',
#                 ',',
#                 'Fc',
#                 ',',
#                 ','),
#                ('application',
#                 'application',
#                 'NN',
#                 44,
#                 303,
#                 314,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 True,
#                 '',
#                 '',
#                 0,
#                 0,
#                 11,
#                 'IN',
#                 'on',
#                 'on',
#                 'NN',
#                 'mode',
#                 'mode',
#                 'NN',
#                 'dependence',
#                 'dependence',
#                 'Fc',
#                 ',',
#                 ',',
#                 'IN',
#                 'in',
#                 'in',
#                 'VBD',
#                 'be',
#                 'was'),
#                ('mode',
#                 'mode',
#                 'NN',
#                 45,
#                 315,
#                 319,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 4,
#                 'NN',
#                 'application',
#                 'application',
#                 'Fc',
#                 ',',
#                 ',',
#                 'IN',
#                 'on',
#                 'on',
#                 'VBD',
#                 'be',
#                 'was',
#                 'NN',
#                 'dependence',
#                 'dependence',
#                 'VBN',
#                 'study',
#                 'studied'),
#                (',',
#                 ',',
#                 'Fc',
#                 46,
#                 319,
#                 320,
#                 'O',
#                 False,
#                 False,
#                 False,
#                 False,
#                 True,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 1,
#                 'NN',
#                 'mode',
#                 'mode',
#                 'VBD',
#                 'be',
#                 'was',
#                 'NN',
#                 'application',
#                 'application',
#                 'VBN',
#                 'study',
#                 'studied',
#                 'IN',
#                 'on',
#                 'on',
#                 'Fp',
#                 '.',
#                 '.'),
#                ('was',
#                 'be',
#                 'VBD',
#                 47,
#                 321,
#                 324,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 3,
#                 'Fc',
#                 ',',
#                 ',',
#                 'VBN',
#                 'study',
#                 'studied',
#                 'NN',
#                 'mode',
#                 'mode',
#                 'Fp',
#                 '.',
#                 '.',
#                 'NN',
#                 'application',
#                 'application',
#                 '',
#                 '',
#                 ''),
#                ('studied',
#                 'study',
#                 'VBN',
#                 48,
#                 325,
#                 332,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 7,
#                 'VBD',
#                 'be',
#                 'was',
#                 'Fp',
#                 '.',
#                 '.',
#                 'Fc',
#                 ',',
#                 ',',
#                 '',
#                 '',
#                 '',
#                 'NN',
#                 'mode',
#                 'mode',
#                 '',
#                 '',
#                 ''),
#                ('.',
#                 '.',
#                 'Fp',
#                 49,
#                 332,
#                 333,
#                 'O',
#                 False,
#                 False,
#                 False,
#                 False,
#                 True,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 1,
#                 'VBN',
#                 'study',
#                 'studied',
#                 '',
#                 '',
#                 '',
#                 'VBD',
#                 'be',
#                 'was',
#                 '',
#                 '',
#                 '',
#                 'Fc',
#                 ',',
#                 ',',
#                 '',
#                 '',
#                 '')],
#   'id': 'DDI-MedLine.d134.s0',
#   'offsets': [(50, 68, ['radiopertechnetate']),
#               (72, 90, ['sodium', 'perchlorate']),
#               (169, 187, ['sodium', 'perchlorate']),
#               (266, 284, ['radiopertechnetate'])],
#   'pairs': [{'ddi': 'false',
#              'e1': 'DDI-MedLine.d134.s0.e0',
#              'e2': 'DDI-MedLine.d134.s0.e1',
#              'id': 'DDI-MedLine.d134.s0.p0'},
#             {'ddi': 'false',
#              'e1': 'DDI-MedLine.d134.s0.e0',
#              'e2': 'DDI-MedLine.d134.s0.e2',
#              'id': 'DDI-MedLine.d134.s0.p1'},
#             {'ddi': 'false',
#              'e1': 'DDI-MedLine.d134.s0.e0',
#              'e2': 'DDI-MedLine.d134.s0.e3',
#              'id': 'DDI-MedLine.d134.s0.p2'},
#             {'ddi': 'false',
#              'e1': 'DDI-MedLine.d134.s0.e1',
#              'e2': 'DDI-MedLine.d134.s0.e2',
#              'id': 'DDI-MedLine.d134.s0.p3'},
#             {'ddi': 'false',
#              'e1': 'DDI-MedLine.d134.s0.e1',
#              'e2': 'DDI-MedLine.d134.s0.e3',
#              'id': 'DDI-MedLine.d134.s0.p4'},
#             {'ddi': 'false',
#              'e1': 'DDI-MedLine.d134.s0.e2',
#              'e2': 'DDI-MedLine.d134.s0.e3',
#              'id': 'DDI-MedLine.d134.s0.p5'}],
#   'text': '[Dose-time effects of competitive displacement of '
#           'radiopertechnetate by sodium perchlorate following oral and '
#           'intravenous administration]\n'
#           'The effect of various doses of sodium perchlorate in several dose '
#           'fractions on the extent and the time scale of displacement of '
#           'radiopertechnetate, in dependence on application mode, was '
#           'studied. ',
#   'token_entities': []},
#  {'Error': False,
#   'bioerrors': 0,
#   'entities': [{'charOffset': '29-39',
#                 'id': 'DDI-MedLine.d134.s1.e0',
#                 'text': 'perchlorate',
#                 'type': 'drug_n'},
#                {'charOffset': '116-128',
#                 'id': 'DDI-MedLine.d134.s1.e1',
#                 'text': 'pertechnetate',
#                 'type': 'drug'},
#                {'charOffset': '237-254',
#                 'id': 'DDI-MedLine.d134.s1.e2',
#                 'text': 'radiopertechnetate',
#                 'type': 'drug'}],
#   'errors': [],
#   'features': [('An',
#                 'a',
#                 'DT',
#                 0,
#                 0,
#                 2,
#                 'O',
#                 True,
#                 False,
#                 False,
#                 False,
#                 False,
#                 False,
#                 '',
#                 'n',
#                 0,
#                 1,
#                 2,
#                 '',
#                 '',
#                 '',
#                 'JJ',
#                 'intravenous',
#                 'intravenous',
#                 '',
#                 '',
#                 '',
#                 'NN',
#                 'dose',
#                 'dose',
#                 '',
#                 '',
#                 '',
#                 'IN',
#                 'of',
#                 'of'),
#                ('intravenous',
#                 'intravenous',
#                 'JJ',
#                 1,
#                 3,
#                 14,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 True,
#                 '',
#                 '',
#                 0,
#                 0,
#                 11,
#                 'DT',
#                 'a',
#                 'An',
#                 'NN',
#                 'dose',
#                 'dose',
#                 '',
#                 '',
#                 '',
#                 'IN',
#                 'of',
#                 'of',
#                 '',
#                 '',
#                 '',
#                 'NN',
#                 '50',
#                 '50'),
#                ('dose',
#                 'dose',
#                 'NN',
#                 2,
#                 15,
#                 19,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 4,
#                 'JJ',
#                 'intravenous',
#                 'intravenous',
#                 'IN',
#                 'of',
#                 'of',
#                 'DT',
#                 'a',
#                 'An',
#                 'NN',
#                 '50',
#                 '50',
#                 '',
#                 '',
#                 '',
#                 'VBG',
#                 'mg',
#                 'mg'),
#                ('of',
#                 'of',
#                 'IN',
#                 3,
#                 20,
#                 22,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NN',
#                 'dose',
#                 'dose',
#                 'NN',
#                 '50',
#                 '50',
#                 'JJ',
#                 'intravenous',
#                 'intravenous',
#                 'VBG',
#                 'mg',
#                 'mg',
#                 'DT',
#                 'a',
#                 'An',
#                 'NN',
#                 'perchlorate',
#                 'perchlorate'),
#                ('50',
#                 '50',
#                 'NN',
#                 4,
#                 23,
#                 25,
#                 'O',
#                 False,
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
# ...
#                 'novel',
#                 'JJ',
#                 '18-mc',
#                 '18-MC',
#                 'NN',
#                 'iboga',
#                 'iboga',
#                 '',
#                 '',
#                 '',
#                 'NN',
#                 'alkaloid',
#                 'alkaloid'),
#                ('novel',
#                 'novel',
#                 'NN',
#                 3,
#                 9,
#                 14,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 5,
#                 'DT',
#                 'a',
#                 'a',
#                 'NN',
#                 'iboga',
#                 'iboga',
#                 'Fc',
#                 ',',
#                 ',',
#                 'NN',
#                 'alkaloid',
#                 'alkaloid',
#                 'JJ',
#                 '18-mc',
#                 '18-MC',
#                 'NN',
#                 'congener',
#                 'congener'),
#                ('iboga',
#                 'iboga',
#                 'NN',
#                 4,
#                 15,
#                 20,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 5,
#                 'NN',
#                 'novel',
#                 'novel',
#                 'NN',
#                 'alkaloid',
#                 'alkaloid',
#                 'DT',
#                 'a',
#                 'a',
#                 'NN',
#                 'congener',
#                 'congener',
#                 'Fc',
#                 ',',
#                 ',',
#                 'Fc',
#                 ',',
#                 ','),
#                ('alkaloid',
#                 'alkaloid',
#                 'NN',
#                 5,
#                 21,
#                 29,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 8,
#                 'NN',
#                 'iboga',
#                 'iboga',
#                 'NN',
#                 'congener',
#                 'congener',
#                 'NN',
#                 'novel',
#                 'novel',
#                 'Fc',
#                 ',',
#                 ',',
#                 'DT',
#                 'a',
#                 'a',
#                 'VBZ',
#                 'be',
#                 'is'),
#                ('congener',
#                 'congener',
#                 'NN',
#                 6,
#                 30,
#                 38,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 8,
#                 'NN',
#                 'alkaloid',
#                 'alkaloid',
#                 'Fc',
#                 ',',
#                 ',',
#                 'NN',
#                 'iboga',
#                 'iboga',
#                 'VBZ',
#                 'be',
#                 'is',
#                 'NN',
#                 'novel',
#                 'novel',
#                 'VBG',
#                 'be',
#                 'being'),
#                (',',
#                 ',',
#                 'Fc',
#                 7,
#                 38,
#                 39,
#                 'O',
#                 False,
#                 False,
#                 False,
#                 False,
#                 True,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 1,
#                 'NN',
#                 'congener',
#                 'congener',
#                 'VBZ',
#                 'be',
#                 'is',
#                 'NN',
#                 'alkaloid',
#                 'alkaloid',
#                 'VBG',
#                 'be',
#                 'being',
#                 'NN',
#                 'iboga',
#                 'iboga',
#                 'VBN',
#                 'develop',
#                 'developed'),
#                ('is',
#                 'be',
#                 'VBZ',
#                 8,
#                 40,
#                 42,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'Fc',
#                 ',',
#                 ',',
#                 'VBG',
#                 'be',
#                 'being',
#                 'NN',
#                 'congener',
#                 'congener',
#                 'VBN',
#                 'develop',
#                 'developed',
#                 'NN',
#                 'alkaloid',
#                 'alkaloid',
#                 'IN',
#                 'as',
#                 'as'),
#                ('being',
#                 'be',
#                 'VBG',
#                 9,
#                 43,
#                 48,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 'ing',
#                 0,
#                 3,
#                 5,
#                 'VBZ',
#                 'be',
#                 'is',
#                 'VBN',
#                 'develop',
#                 'developed',
#                 'Fc',
#                 ',',
#                 ',',
#                 'IN',
#                 'as',
#                 'as',
#                 'NN',
#                 'congener',
#                 'congener',
#                 'DT',
#                 'a',
#                 'a'),
#                ('developed',
#                 'develop',
#                 'VBN',
#                 10,
#                 49,
#                 58,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 'ed',
#                 0,
#                 2,
#                 9,
#                 'VBG',
#                 'be',
#                 'being',
#                 'IN',
#                 'as',
#                 'as',
#                 'VBZ',
#                 'be',
#                 'is',
#                 'DT',
#                 'a',
#                 'a',
#                 'Fc',
#                 ',',
#                 ',',
#                 'JJ',
#                 'potential',
#                 'potential'),
#                ('as',
#                 'as',
#                 'IN',
#                 11,
#                 59,
#                 61,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'VBN',
#                 'develop',
#                 'developed',
#                 'DT',
#                 'a',
#                 'a',
#                 'VBG',
#                 'be',
#                 'being',
#                 'JJ',
#                 'potential',
#                 'potential',
#                 'VBZ',
#                 'be',
#                 'is',
#                 'NN',
#                 'treatment',
#                 'treatment'),
#                ('a',
#                 'a',
#                 'DT',
#                 12,
#                 62,
#                 63,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 1,
#                 'IN',
#                 'as',
#                 'as',
#                 'JJ',
#                 'potential',
#                 'potential',
#                 'VBN',
#                 'develop',
#                 'developed',
#                 'NN',
#                 'treatment',
#                 'treatment',
#                 'VBG',
#                 'be',
#                 'being',
#                 'IN',
#                 'for',
#                 'for'),
#                ('potential',
#                 'potential',
#                 'JJ',
#                 13,
#                 64,
#                 73,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 9,
#                 'DT',
#                 'a',
#                 'a',
#                 'NN',
#                 'treatment',
#                 'treatment',
#                 'IN',
#                 'as',
#                 'as',
#                 'IN',
#                 'for',
#                 'for',
#                 'VBN',
#                 'develop',
#                 'developed',
#                 'JJ',
#                 'multiple',
#                 'multiple'),
#                ('treatment',
#                 'treatment',
#                 'NN',
#                 14,
#                 74,
#                 83,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 9,
#                 'JJ',
#                 'potential',
#                 'potential',
#                 'IN',
#                 'for',
#                 'for',
#                 'DT',
#                 'a',
#                 'a',
#                 'JJ',
#                 'multiple',
#                 'multiple',
#                 'IN',
#                 'as',
#                 'as',
#                 'NNS',
#                 'form',
#                 'forms'),
#                ('for',
#                 'for',
#                 'IN',
#                 15,
#                 84,
#                 87,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 3,
#                 'NN',
#                 'treatment',
#                 'treatment',
#                 'JJ',
#                 'multiple',
#                 'multiple',
#                 'JJ',
#                 'potential',
#                 'potential',
#                 'NNS',
#                 'form',
#                 'forms',
#                 'DT',
#                 'a',
#                 'a',
#                 'IN',
#                 'of',
#                 'of'),
#                ('multiple',
#                 'multiple',
#                 'JJ',
#                 16,
#                 88,
#                 96,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 8,
#                 'IN',
#                 'for',
#                 'for',
#                 'NNS',
#                 'form',
#                 'forms',
#                 'NN',
#                 'treatment',
#                 'treatment',
#                 'IN',
#                 'of',
#                 'of',
#                 'JJ',
#                 'potential',
#                 'potential',
#                 'NN',
#                 'drug',
#                 'drug'),
#                ('forms',
#                 'form',
#                 'NNS',
#                 17,
#                 97,
#                 102,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 's',
#                 0,
#                 1,
#                 5,
#                 'JJ',
#                 'multiple',
#                 'multiple',
#                 'IN',
#                 'of',
#                 'of',
#                 'IN',
#                 'for',
#                 'for',
#                 'NN',
#                 'drug',
#                 'drug',
#                 'NN',
#                 'treatment',
#                 'treatment',
#                 'NN',
#                 'abuse',
#                 'abuse'),
#                ('of',
#                 'of',
#                 'IN',
#                 18,
#                 103,
#                 105,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 2,
#                 'NNS',
#                 'form',
#                 'forms',
#                 'NN',
#                 'drug',
#                 'drug',
#                 'JJ',
#                 'multiple',
#                 'multiple',
#                 'NN',
#                 'abuse',
#                 'abuse',
#                 'IN',
#                 'for',
#                 'for',
#                 'Fp',
#                 '.',
#                 '.'),
#                ('drug',
#                 'drug',
#                 'NN',
#                 19,
#                 106,
#                 110,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 4,
#                 'IN',
#                 'of',
#                 'of',
#                 'NN',
#                 'abuse',
#                 'abuse',
#                 'NNS',
#                 'form',
#                 'forms',
#                 'Fp',
#                 '.',
#                 '.',
#                 'JJ',
#                 'multiple',
#                 'multiple',
#                 '',
#                 '',
#                 ''),
#                ('abuse',
#                 'abuse',
#                 'NN',
#                 20,
#                 111,
#                 116,
#                 'O',
#                 False,
#                 False,
#                 True,
#                 False,
#                 False,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 5,
#                 'NN',
#                 'drug',
#                 'drug',
#                 'Fp',
#                 '.',
#                 '.',
#                 'IN',
#                 'of',
#                 'of',
#                 '',
#                 '',
#                 '',
#                 'NNS',
#                 'form',
#                 'forms',
#                 '',
#                 '',
#                 ''),
#                ('.',
#                 '.',
#                 'Fp',
#                 21,
#                 116,
#                 117,
#                 'O',
#                 False,
#                 False,
#                 False,
#                 False,
#                 True,
#                 False,
#                 '',
#                 '',
#                 0,
#                 0,
#                 1,
#                 'NN',
#                 'abuse',
#                 'abuse',
#                 '',
#                 '',
#                 '',
#                 'NN',
#                 'drug',
#                 'drug',
#                 '',
#                 '',
#                 '',
#                 'IN',
#                 'of',
#                 'of',
#                 '',
#                 '',
#                 '')],
#   'id': 'DDI-MedLine.d110.s1',
#   'offsets': [(0, 5, ['18-MC'])],
#   'pairs': [],
#   'text': '18-MC, a novel iboga alkaloid congener, is being developed as a '
#           'potential treatment for multiple forms of drug abuse. ',
#   'token_entities': []}]

# %%
fe.save('../data/models/data-test.json')

# %%
import SVMtrainer
vectorizeddata = SVMtrainer.dataFormatting(datafile='../data/models/data-test.json')
SVMtrainer.saveVectorizedData(vectorizeddata,'../data/models/data-test.pkl')
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 7159
# True

# %%
vdata=SVMtrainer.loadVectorizedData('../data/models/data-test.pkl')
vdata[1]
# Out:
# <7159x23573 sparse matrix of type '<class 'numpy.float64'>'
# 	with 201940 stored elements in Compressed Sparse Row format>

# %%
clf = SVMtrainer.trainSVM(vdata)
SVMtrainer.saveModel(clf,'../data/models/svm-20180509.pkl')
# Out:
#              precision    recall  f1-score   support
#
#           B       0.00      0.00      0.00       465
#           I       0.00      0.00      0.00       121
#           O       0.92      1.00      0.96      6573
#
# avg / total       0.84      0.92      0.88      7159
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# input test files folder  and prepare for prediction

# %%
clf2 = SVMTrainer.loadModel('../data/models/svm-20180509.pkl')
# prepare some test set with the data preparation routines
clf2.predict(X[0:1])
