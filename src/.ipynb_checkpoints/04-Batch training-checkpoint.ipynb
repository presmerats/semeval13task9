# %%
# generate feature subsets
from CustomFeatures import MyFeatures
from NERmodel import NERmodel
import subprocess
import traceback, sys
import pickle
import yaml
import os

def initConf(filepath=None):
    """
        every plugin uses its own config file
    """
    if not filepath:
        return yaml.load(open(os.getcwd()+'/models.conf','r'))
    else:
        return yaml.load(open(filepath,'r'))
    
def writeConfBack(conf, filepath=None):
    if not filepath:
        filepath = os.getcwd()+'/models.conf'
    with open(filepath,'w') as f:
        f.write(yaml.dump(conf))
        
     
def writeConf(conf,modelname,key, msg ):
    for modeln,params in conf["models"].items():
        try:
            if modelname == modeln:
                params[key]=msg
                writeConfBack(conf)
        except Exception:
            print("Exception in user code:")
            print("-"*60)
            traceback.print_exc(file=sys.stdout)
            print("-"*60) 
        

conf = initConf()


# name the batch training
training_set_name =  conf["session"]
print(training_set_name)

# load the different MyFeature instances
fs = []
#for i in range(len(conf["models"])):
for modelname,params in conf["models"].items():
    #print(modelname)
    #print(params["word"])
    try:
        mf = MyFeatures(params=params)
        #print(mf)
        #print(modelname)
        fs.append((mf,modelname,params["modeltype"]))
        #print("Active features")
        #print(mf.printActiveFeatureFunctions())
        #print()
        writeConf(conf,modelname,"status", "doing" )
    except Exception:
        print("Exception in user code:")
        print("-"*60)
        traceback.print_exc(file=sys.stdout)
        print("-"*60)
        writeConf(conf,modelname,"status", "error" )
        
print("feature instances:")
print(fs)
print()    

# initialize
models=[]
for mf in fs:
    try:
        fset=mf[0]
        modelname=mf[1]
        modeltype=mf[2]
        model = NERmodel(featureset=fset, name=modelname, modeltype=modeltype)
        model.setName(training_set_name)
        models.append(model)
    except:
        writeConf(conf,modelname,"status", "error" )
         
fsold = fs
fs = [mf[0] for mf in fs]
print("models:")
print(models)
print()
    

# train all models
models_pickles =[None]*len(models)
print(len(models_pickles))
print(models_pickles)
for i in range(len(models)):
    model = models[i]
    try:
        model.trainFeatureExtraction(
            conf["trainingFolder"], 
            limit=50)
        model.saveTrainingFeatures(conf["savingFolder"] +"/" +conf["session"]+"-"+model.name+".json")
        model.newModelPipeline(ertype=model.modeltype
)
        models_pickles[i] = model.saveModelPipeline()
    except Exception:
        print("Exception in user code:",i)
        print("-"*60)
        traceback.print_exc(file=sys.stdout)
        print("-"*60)
        print("model "+str(i)+" has failed... ")
        models_pickles[i] = None
        
        writeConf(conf,modelname,"status", "error" )
        
        
print("model pickles:")
print(models_pickles)
print()

# test all models
# PROBLEM I need the same feature set! so maybe the 
# pipeline should be pickled with the featureset
# so maybe we should use pickle of the whole NER?
results_files = [None]*len(models)
evaluation_files = [None]*len(models)
for i in range(len(models_pickles)):
    modelfile = models_pickles[i]
    fset = fs[i]
    try:
        print(fsold[i][2])
        model = NERmodel(featureset=fs[i], name=fsold[i][1], modeltype=fsold[i][2])
        model.loadModelPipeline(filepath=modelfile)
        model.testFeatureExtraction(
            conf["testFolder"], 
            limit=40)
        model.predict()
        model.parsePredictionOutput(conf["savingFolder"]+'/task9.1_'+training_set_name+'_'+str(i)+'.txt')
        results_files[i] = conf["savingFolder"]+ "/" + conf["session"]+"-"+model.name+'-output.csv'
        print("model "+model.name+":")
        evaluation_files[i] = model.autoEvaluation()
        
        writeConf(conf,modelname,"status", "done" )
    except  Exception:
        print("Exception in user code:",i)
        print("-"*60)
        traceback.print_exc(file=sys.stdout)
        print("-"*60)
        
        writeConf(conf,modelname,"status", "error" )
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# testyaml20180516
# feature instances:
# [(<CustomFeatures.MyFeatures object at 0x7ff692c2aeb8>, 'mod001', 'NER'), (<CustomFeatures.MyFeatures object at 0x7ff692b95128>, 'mod002', 'NER')]
#
# models:
# [<NERmodel.NERmodel object at 0x7ff692b98080>, <NERmodel.NERmodel object at 0x7ff692b982b0>]
#
# 2
# [None, None]
# model pickles:
# ['../data/models/svm-pipeline_20180517002106.pkl', '../data/models/svm-pipeline_20180517002113.pkl']
#
# NER
# NER
# the model is NER
# predict ertype=NER
# model mod001:
# None
# NER
# NER
# the model is NER
# predict ertype=NER
# model mod002:
# None

# %%
# generate feature subsets
from CustomFeatures import MyFeatures
from NERmodel import NERmodel
import subprocess
import traceback, sys
import pickle
import yaml
import os

def initConf(filepath=None):
    """
        every plugin uses its own config file
    """
    if not filepath:
        return yaml.load(open(os.getcwd()+'/models.conf','r'))
    else:
        return yaml.load(open(filepath,'r'))
    
def writeConfBack(conf, filepath=None):
    if not filepath:
        filepath = os.getcwd()+'/models.conf'
    with open(filepath,'w') as f:
        f.write(yaml.dump(conf))
        
     
def writeConf(conf,modelname,key, msg ):
    for modeln,params in conf["models"].items():
        try:
            if modelname == modeln:
                params[key]=msg
                writeConfBack(conf)
        except Exception:
            print("Exception in user code:")
            print("-"*60)
            traceback.print_exc(file=sys.stdout)
            print("-"*60) 
        

conf = initConf('debug_batch3.yaml')


# name the batch training
training_set_name =  conf["session"]
print(training_set_name)

# load the different MyFeature instances
fs = []
#for i in range(len(conf["models"])):
for modelname,params in conf["models"].items():
    try:
        mf = MyFeatures(params=params)
        fs.append((mf,modelname,params["modeltype"],params))
        writeConf(conf,modelname,"status", "doing" )
    except Exception:
        print("Exception in user code:")
        print("-"*60)
        traceback.print_exc(file=sys.stdout)
        print("-"*60)
        writeConf(conf,modelname,"status", "error" )
        
print([e[1] for e in fs])   

# initialize
models=[]
models_pickles =[None]*len(fs)
results_files = [None]*len(fs)
evaluation_files = [None]*len(fs)
for i in range(len(fs)):
    mf = fs[i]
    try:
        fset=mf[0]
        modelname=mf[1]
        modeltype=mf[2]
        limitTrain=None
        if "limitTraining" in mf[3].keys():
            limitTrain = mf[3]["limitTraining"]
        limitTest=None
        if "limitTest" in mf[3].keys():
            limitTest = mf[3]["limitTest"]
        model = NERmodel(featureset=fset, name=modelname, modeltype=modeltype)
        model.setName(training_set_name)
        models.append(model)
        
        model.trainFeatureExtraction(
            conf["trainingFolder"], 
            limit=limitTrain)
        model.saveTrainingFeatures(conf["savingFolder"] +"/" +conf["session"]+"-"+model.name+".json")
        model.newModelPipeline(ertype=model.modeltype)
        models_pickles[i] = model.saveModelPipeline()
        modelfile=models_pickles[i]
        
        model.testFeatureExtraction(
            conf["testFolder"], 
            limit=limitTest)
        
        model.predict()
        
        # debug
        print(model.predictionResults[:10])
        
        model.parsePredictionOutput(conf["savingFolder"]+'/task9.1_'+training_set_name+model.name+'_'+str(i)+'.txt')
        results_files[i] = conf["savingFolder"]+ "/" + conf["session"]+"-"+model.name+'-output.csv'
        print("model "+model.name+":")
        evaluation_files[i], accuracy = model.autoEvaluation()
        writeConf(conf,modelname,"accuracy", accuracy)
        
        writeConf(conf,modelname,"status", "done" )
        
        
    except Exception:
        print("Exception in user code:",i)
        print("-"*60)
        traceback.print_exc(file=sys.stdout)
        print("-"*60)
        print("model "+str(i)+" has failed... ")
        models_pickles[i] = None
        writeConf(conf,modelname,"status", "error" )
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# bm3
# ['mod000', 'mod001', 'mod002']
# target and models
# ['O', 'O', 'O']
# [{'word': '[', 'lemma': '[', 'pos': 'Fca', 'sentenceid': 'DDI-MedLine.d134.s0', 'offsetstart': 0, 'offsetend': 1, 'drugtype': '', 'chunk': '', 'chunkGroup': '', 'isTitleCase': False, 'isUpperCase': False, 'isLowerCase': True, 'hasDigits': False, 'hasStrangeChars': '', 'moreThan10chars': '', 'lensuffix': 0, 'lenword': 9, 'wordStructure': '', 'prefix': '', 'suffix': '', 'lenprefix': 0}, {'word': 'Dose-time', 'lemma': 'dose-time', 'pos': 'NP', 'sentenceid': 'DDI-MedLine.d134.s0', 'offsetstart': 1, 'offsetend': 10, 'drugtype': '', 'chunk': '', 'chunkGroup': '', 'isTitleCase': False, 'isUpperCase': False, 'isLowerCase': True, 'hasDigits': False, 'hasStrangeChars': '', 'moreThan10chars': '', 'lensuffix': 1, 'lenword': 7, 'wordStructure': '', 'prefix': '', 'suffix': 's', 'lenprefix': 0}]
#
# Exception in user code: 0
# ------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-1-84dfc0e9ee14>", line 94, in <module>
#     limit=limitTest)
#   File "/media/disk/home/pau/Projectes/AHLT-mai/src/NERmodel.py", line 87, in testFeatureExtraction
#     self.testdata.extractFeatures(limit)
#   File "/media/disk/home/pau/Projectes/AHLT-mai/src/FeatureExtraction.py", line 134, in extractFeatures
#     self.data = self.data[:limit]
# TypeError: slice indices must be integers or None or have an __index__ method
# ------------------------------------------------------------
# model 0 has failed...
# target and models
# ['O', 'O', 'O']
# [{'word': '[', 'lemma': '[', 'pos': 'Fca', 'sentenceid': 'DDI-MedLine.d134.s0', 'offsetstart': 0, 'offsetend': 1, 'drugtype': '', 'chunk': '', 'chunkGroup': '', 'isTitleCase': False, 'isUpperCase': False, 'isLowerCase': True, 'hasDigits': False, 'hasStrangeChars': '', 'moreThan10chars': '', 'lensuffix': 0, 'lenword': 9, 'wordStructure': '', 'prefix': '', 'suffix': '', 'lenprefix': 0}, {'word': 'Dose-time', 'lemma': 'dose-time', 'pos': 'NP', 'sentenceid': 'DDI-MedLine.d134.s0', 'offsetstart': 1, 'offsetend': 10, 'drugtype': '', 'chunk': '', 'chunkGroup': '', 'isTitleCase': False, 'isUpperCase': False, 'isLowerCase': True, 'hasDigits': False, 'hasStrangeChars': '', 'moreThan10chars': '', 'lensuffix': 1, 'lenword': 7, 'wordStructure': '', 'prefix': '', 'suffix': 's', 'lenprefix': 0}]
#
# Exception in user code: 1
# ------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-1-84dfc0e9ee14>", line 94, in <module>
#     limit=limitTest)
#   File "/media/disk/home/pau/Projectes/AHLT-mai/src/NERmodel.py", line 87, in testFeatureExtraction
#     self.testdata.extractFeatures(limit)
#   File "/media/disk/home/pau/Projectes/AHLT-mai/src/FeatureExtraction.py", line 134, in extractFeatures
#     self.data = self.data[:limit]
# TypeError: slice indices must be integers or None or have an __index__ method
# ------------------------------------------------------------
# model 1 has failed...
# target and models
# ['O', 'O', 'O']
# [{'word': '[', 'lemma': '[', 'pos': 'Fca', 'sentenceid': 'DDI-MedLine.d134.s0', 'offsetstart': 0, 'offsetend': 1, 'drugtype': '', 'chunk': '', 'chunkGroup': '', 'isTitleCase': False, 'isUpperCase': False, 'isLowerCase': True, 'hasDigits': False, 'hasStrangeChars': '', 'moreThan10chars': '', 'lensuffix': 0, 'lenword': 9, 'wordStructure': '', 'prefix': '', 'suffix': '', 'lenprefix': 0}, {'word': 'Dose-time', 'lemma': 'dose-time', 'pos': 'NP', 'sentenceid': 'DDI-MedLine.d134.s0', 'offsetstart': 1, 'offsetend': 10, 'drugtype': '', 'chunk': '', 'chunkGroup': '', 'isTitleCase': False, 'isUpperCase': False, 'isLowerCase': True, 'hasDigits': False, 'hasStrangeChars': '', 'moreThan10chars': '', 'lensuffix': 1, 'lenword': 7, 'wordStructure': '', 'prefix': '', 'suffix': 's', 'lenprefix': 0}]
#
# ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O']
#  non O tags:
# 114
# matchdict
# 60
# [[43, 52, 'estradiol', 'null', 'B'], [62, 74, 'progesterone', 'null', 'B'], [114, 125, 'terconazole', 'null', 'B']]
# predictions length 114
# [['DDI-DrugBank.d772.s1', 43, 52, 'estradiol', 'null'], ['DDI-DrugBank.d772.s1', 62, 74, 'progesterone', 'null']]
# DDI-DrugBank.d772.s1|43-52|estradiol|null
# DDI-DrugBank.d772.s1|62-74|progesterone|null
# DDI-DrugBank.d772.s1|114-125|terconazole|null
# DDI-DrugBank.d646.s0|79-88|rifaximin|null
# DDI-DrugBank.d646.s1|71-80|rifaximin|null
# DDI-DrugBank.d681.s0|18-28|cimetidine|null
# DDI-DrugBank.d681.s0|30-37|digoxin|null
# DDI-DrugBank.d681.s0|74-83|sevelamer|null
# DDI-DrugBank.d681.s0|89-101|theophylline|null
# DDI-DrugBank.d745.s0|55-59|SAMe|null
# DDI-DrugBank.d657.s0|17-27|Dronabinol|null
# DDI-DrugBank.d657.s0|94-104|Dronabinol|null
# DDI-DrugBank.d592.s0|17-42|Sodium_Tetradecyl_Sulfate|null
# DDI-DrugBank.d592.s2|54-79|Sodium_Tetradecyl_Sulfate|null
# DDI-DrugBank.d684.s3|32-44|erythromycin|null
# DDI-DrugBank.d684.s3|46-58|itraconazole|null
# DDI-DrugBank.d684.s3|60-72|ketoconazole|null
# DDI-DrugBank.d684.s3|74-85|fluconazole|null
# DDI-DrugBank.d684.s3|116-126|cimetidine|null
# DDI-DrugBank.d621.s1|26-36|colestipol|null
# DDI-DrugBank.d621.s1|38-52|cholestyramine|null
# DDI-DrugBank.d621.s1|54-61|mineral|null
# DDI-DrugBank.d621.s1|62-65|oil|null
# DDI-DrugBank.d621.s1|71-81|sucralfate|null
# DDI-DrugBank.d593.s0|122-129|digoxin|null
# DDI-DrugBank.d692.s1|31-43|moxifloxacin|null
# DDI-DrugBank.d667.s0|43-51|oxytocin|null
# DDI-DrugBank.d667.s1|35-43|oxytocin|null
# DDI-DrugBank.d667.s2|91-99|oxytocin|null
# DDI-DrugBank.d617.s3|22-35|nitroglycerin|null
# DDI-DrugBank.d617.s4|16-26|furosemide|null
# DDI-DrugBank.d617.s4|28-47|hydrochlorothiazide|null
# DDI-DrugBank.d617.s4|49-63|spironolactone|null
# DDI-DrugBank.d617.s6|19-27|diazepam|null
# DDI-DrugBank.d617.s6|29-36|insulin|null
# DDI-DrugBank.d612.s0|58-70|pioglitazone|null
# DDI-DrugBank.d731.s1|68-77|cisplatin|null
# DDI-DrugBank.d626.s0|54-64|primaquine|null
# DDI-DrugBank.d663.s1|64-75|verteporfin|null
# DDI-DrugBank.d663.s3|96-107|verteporfin|null
# DDI-DrugBank.d583.s0|49-64|succinylcholine|null
# DDI-DrugBank.d583.s0|85-97|remifentanil|null
# DDI-DrugBank.d583.s1|71-81|thiopental|null
# DDI-DrugBank.d583.s1|83-93|isoflurane|null
# DDI-DrugBank.d583.s1|95-103|propofol|null
# DDI-DrugBank.d583.s1|108-117|temazepam|null
# DDI-DrugBank.d583.s2|22-32|atracurium|null
# DDI-DrugBank.d583.s2|34-44|mivacurium|null
# DDI-DrugBank.d583.s2|46-53|esmolol|null
# DDI-DrugBank.d583.s2|55-68|echothiophate|null
# DDI-DrugBank.d583.s2|70-81|neostigmine|null
# DDI-DrugBank.d583.s2|83-96|physostigmine|null
# DDI-DrugBank.d583.s2|102-111|midazolam|null
# DDI-DrugBank.d673.s0|67-77|olmesartan|null
# DDI-DrugBank.d673.s0|78-87|medoxomil|null
# DDI-DrugBank.d673.s0|113-120|digoxin|null
# DDI-DrugBank.d673.s1|23-33|olmesartan|null
# DDI-DrugBank.d614.s6|94-104|b-carotene|null
# DDI-DrugBank.d614.s6|106-113|ethanol|null
# DDI-DrugBank.d614.s7|52-63|allopurinol|null
# DDI-DrugBank.d594.s0|37-48|fludarabine|null
# DDI-DrugBank.d594.s0|53-63|vidarabine|null
# DDI-DrugBank.d705.s0|94-105|telbivudine|null
# DDI-DrugBank.d705.s1|17-28|telbivudine|null
# DDI-DrugBank.d705.s1|96-107|telbivudine|null
# DDI-DrugBank.d586.s1|36-48|pimecrolimus|null
# DDI-DrugBank.d586.s3|32-44|erythromycin|null
# DDI-DrugBank.d586.s3|46-58|itraconazole|null
# DDI-DrugBank.d586.s3|60-72|ketoconazole|null
# DDI-DrugBank.d586.s3|74-85|fluconazole|null
# DDI-DrugBank.d586.s3|116-126|cimetidine|null
# DDI-DrugBank.d767.s1|20-31|vincristine|null
# DDI-DrugBank.d767.s1|32-39|sulfate|null
# DDI-DrugBank.d767.s2|54-63|phenytoin|null
# DDI-DrugBank.d730.s0|31-40|temazepam|null
# DDI-DrugBank.d730.s0|94-104|cimetidine|null
# DDI-DrugBank.d701.s0|20-31|Pirenzepine|null
# DDI-DrugBank.d701.s0|102-113|Pirenzepine|null
# DDI-DrugBank.d701.s1|42-48|kaolin|null
# DDI-DrugBank.d701.s1|52-63|attapulgite|null
# DDI-DrugBank.d701.s1|66-78|Ketoconazole|null
# DDI-DrugBank.d718.s0|51-58|Calcium|null
# DDI-DrugBank.d718.s0|72-86|Cholestyramine|null
# DDI-DrugBank.d718.s0|88-95|Choline|null
# DDI-DrugBank.d718.s0|100-109|magnesium|null
# DDI-DrugBank.d718.s1|31-39|estrogen|null
# DDI-DrugBank.d644.s2|62-70|Rifampin|null
# DDI-DrugBank.d644.s2|84-93|phenytoin|null
# DDI-DrugBank.d644.s2|105-118|carbamazepine|null
# DDI-DrugBank.d644.s4|106-114|warfarin|null
# DDI-DrugBank.d664.s0|60-68|warfarin|null
# DDI-DrugBank.d664.s1|67-75|warfarin|null
# DDI-DrugBank.d672.s0|63-70|digoxin|null
# DDI-DrugBank.d672.s1|17-29|Sparfloxacin|null
# DDI-DrugBank.d672.s1|55-67|theophylline|null
# DDI-DrugBank.d672.s2|35-47|theophylline|null
# DDI-DrugBank.d672.s2|96-104|caffeine|null
# DDI-DrugBank.d672.s3|70-78|warfarin|null
# DDI-DrugBank.d672.s4|12-22|Cimetidine|null
# DDI-DrugBank.d672.s4|63-75|sparfloxacin|null
# DDI-DrugBank.d672.s5|28-40|sparfloxacin|null
# DDI-DrugBank.d672.s7|42-54|sparfloxacin|null
# DDI-DrugBank.d672.s8|12-22|Probenecid|null
# DDI-DrugBank.d672.s8|62-74|sparfloxacin|null
# DDI-DrugBank.d733.s2|68-78|diclofenac|null
# DDI-DrugBank.d733.s2|82-91|ibuprofen|null
# DDI-DrugBank.d764.s0|49-55|methyl|null
# DDI-DrugBank.d764.s0|56-71|aminolevulinate|null
# DDI-DrugBank.d768.s1|32-44|palonosetron|null
# DDI-DrugBank.d768.s2|75-87|palonosetron|null
# DDI-DrugBank.d768.s3|55-67|palonosetron|null
# DDI-DrugBank.d768.s3|100-114|metoclopramide|null
# DDI-DrugBank.d768.s5|96-105|cisplatin|null
# DDI-DrugBank.d768.s5|107-123|cyclophosphamide|null
# model bm3:
# 0.0

# %%
# generate feature subsets
from CustomFeatures import MyFeatures
from NERmodel import NERmodel
import subprocess
import traceback, sys
import pickle
import yaml
import os

# quick tests (no match but fast)
NERmodel.batchTraining('../data/batches/debug_batch4.yaml')
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# bm2debug
# ['mod001', 'mod002', 'mod003', 'mod004', 'mod005']
# [{'biotag': 'O',
#   'chunk_word': '',
#   'drugtype': '',
#   'hasDigits_before1': '',
#   'hasStrangeChars_before1': '',
#   'isLowerCase_before1': '',
#   'isTitleCase_before1': '',
#   'lookup_word': False,
#   'offsetend': 1,
#   'offsetstart': 0,
#   'pos_after1': 'NP',
#   'pos_after2': 'NNS',
#   'pos_after3': 'IN',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'word': '[',
#   'wordStructure_word': '_'}]
# [{'biotag': 'O',
#   'chunk_word': 'NE',
#   'drugtype': '',
#   'hasDigits_before1': '',
#   'hasStrangeChars_before1': '',
#   'isLowerCase_before1': '',
#   'isTitleCase_before1': '',
#   'lookup_word': False,
#   'offsetend': 4,
#   'offsetstart': 0,
#   'pos_after1': 'NN',
#   'pos_after2': 'NNS',
#   'pos_after3': 'VBP',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'sentenceid': 'DDI-DrugBank.d749.s0',
#   'word': 'Drug',
#   'wordStructure_word': 'Xx'}]
#  non O tags:
# 0
# matchdict
# 0
# predictions length 0
# ...
# model bm2debug:
# 0.0
#
#
# Exception in user code: 0
# ------------------------------------------------------------
# Traceback (most recent call last):
#   File "/media/disk/home/pau/Projectes/AHLT-mai/src/NERmodel.py", line 410, in batchTraining
#     NERmodel.writeConf(conf,modelname,"status", "done" ).predictionResultFile+'_result'
# AttributeError: 'NoneType' object has no attribute 'predictionResultFile'
# ------------------------------------------------------------
# model 0 has failed...
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': True,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': True,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': True,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': False,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'dose-time',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 9,
#   'lenword_before1': '',
#   'lenword_word': 1,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 1,
#   'offsetstart': 0,
#   'pos_after1': 'NP',
#   'pos_after2': 'NNS',
#   'pos_after3': 'IN',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': '[',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': '_'}]
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': False,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': False,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': False,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': True,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'interaction',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 11,
#   'lenword_before1': '',
#   'lenword_word': 4,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 4,
#   'offsetstart': 0,
#   'pos_after1': 'NN',
#   'pos_after2': 'NNS',
#   'pos_after3': 'VBP',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-DrugBank.d749.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': 'Drug',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': 'Xx'}]
#  non O tags:
# 0
# matchdict
# 0
# predictions length 0
# ...
# model bm2debug:
# 0.0
#
#
# Exception in user code: 1
# ------------------------------------------------------------
# Traceback (most recent call last):
#   File "/media/disk/home/pau/Projectes/AHLT-mai/src/NERmodel.py", line 410, in batchTraining
#     NERmodel.writeConf(conf,modelname,"status", "done" ).predictionResultFile+'_result'
# AttributeError: 'NoneType' object has no attribute 'predictionResultFile'
# ------------------------------------------------------------
# model 1 has failed...
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': True,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': True,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': True,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': False,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'dose-time',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 9,
#   'lenword_before1': '',
#   'lenword_word': 1,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 1,
#   'offsetstart': 0,
#   'pos_after1': 'NP',
#   'pos_after2': 'NNS',
#   'pos_after3': 'IN',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': '[',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': '_'}]
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': False,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': False,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': False,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': True,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'interaction',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 11,
#   'lenword_before1': '',
#   'lenword_word': 4,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 4,
#   'offsetstart': 0,
#   'pos_after1': 'NN',
#   'pos_after2': 'NNS',
#   'pos_after3': 'VBP',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-DrugBank.d749.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': 'Drug',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': 'Xx'}]
#  non O tags:
# 0
# matchdict
# 0
# predictions length 0
# ...
# model bm2debug:
# 0.0
#
#
# Exception in user code: 2
# ------------------------------------------------------------
# Traceback (most recent call last):
#   File "/media/disk/home/pau/Projectes/AHLT-mai/src/NERmodel.py", line 410, in batchTraining
#     NERmodel.writeConf(conf,modelname,"status", "done" ).predictionResultFile+'_result'
# AttributeError: 'NoneType' object has no attribute 'predictionResultFile'
# ------------------------------------------------------------
# model 2 has failed...
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': True,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': True,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': True,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': False,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'dose-time',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 9,
#   'lenword_before1': '',
#   'lenword_word': 1,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 1,
#   'offsetstart': 0,
#   'pos_after1': 'NP',
#   'pos_after2': 'NNS',
#   'pos_after3': 'IN',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': '[',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': '_'}]
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': False,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': False,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': False,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': True,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'interaction',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 11,
#   'lenword_before1': '',
#   'lenword_word': 4,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 4,
#   'offsetstart': 0,
#   'pos_after1': 'NN',
#   'pos_after2': 'NNS',
#   'pos_after3': 'VBP',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-DrugBank.d749.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': 'Drug',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': 'Xx'}]
#  non O tags:
# 0
# matchdict
# 0
# predictions length 0
# ...
# model bm2debug:
# 0.0
#
#
# Exception in user code: 3
# ------------------------------------------------------------
# Traceback (most recent call last):
#   File "/media/disk/home/pau/Projectes/AHLT-mai/src/NERmodel.py", line 410, in batchTraining
#     NERmodel.writeConf(conf,modelname,"status", "done" ).predictionResultFile+'_result'
# AttributeError: 'NoneType' object has no attribute 'predictionResultFile'
# ------------------------------------------------------------
# model 3 has failed...
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': True,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': True,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': True,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': False,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'dose-time',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 9,
#   'lenword_before1': '',
#   'lenword_word': 1,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 1,
#   'offsetstart': 0,
#   'pos_after1': 'NP',
#   'pos_after2': 'NNS',
#   'pos_after3': 'IN',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': '[',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': '_'}]
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': False,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': False,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': False,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': True,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'interaction',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 11,
#   'lenword_before1': '',
#   'lenword_word': 4,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 4,
#   'offsetstart': 0,
#   'pos_after1': 'NN',
#   'pos_after2': 'NNS',
#   'pos_after3': 'VBP',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-DrugBank.d749.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': 'Drug',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': 'Xx'}]
#  non O tags:
# 0
# matchdict
# 0
# predictions length 0
# ...
# model bm2debug:
# 0.0
#
#
# Exception in user code: 4
# ------------------------------------------------------------
# Traceback (most recent call last):
#   File "/media/disk/home/pau/Projectes/AHLT-mai/src/NERmodel.py", line 410, in batchTraining
#     NERmodel.writeConf(conf,modelname,"status", "done" ).predictionResultFile+'_result'
# AttributeError: 'NoneType' object has no attribute 'predictionResultFile'
# ------------------------------------------------------------
# model 4 has failed...

# %%
# generate feature subsets
from CustomFeatures import MyFeatures
from NERmodel import NERmodel
import subprocess
import traceback, sys
import pickle
import yaml
import os

# quick result parsing (fastests matchings found)
NERmodel.batchTraining('../data/batches/debug_batch3.yaml')
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# bm3
# ['mod000', 'mod001', 'mod002']
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': True,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': True,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': True,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': False,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'dose-time',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 9,
#   'lenword_before1': '',
#   'lenword_word': 1,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 1,
#   'offsetstart': 0,
#   'pos_after1': 'NP',
#   'pos_after2': 'NNS',
#   'pos_after3': 'IN',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': '[',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': '_'}]
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': False,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': False,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': False,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': True,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'interaction',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 11,
#   'lenword_before1': '',
#   'lenword_word': 4,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 4,
#   'offsetstart': 0,
#   'pos_after1': 'NN',
#   'pos_after2': 'NNS',
#   'pos_after3': 'VBP',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-DrugBank.d749.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': 'Drug',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': 'Xx'}]
#  non O tags:
# 0
# matchdict
# 0
# predictions length 0
# ...
# model bm3:
# 0.0
#
#
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': True,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': True,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': True,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': False,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'dose-time',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 9,
#   'lenword_before1': '',
#   'lenword_word': 1,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 1,
#   'offsetstart': 0,
#   'pos_after1': 'NP',
#   'pos_after2': 'NNS',
#   'pos_after3': 'IN',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': '[',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': '_'}]
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': False,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': False,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': False,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': True,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'interaction',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 11,
#   'lenword_before1': '',
#   'lenword_word': 4,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 4,
#   'offsetstart': 0,
#   'pos_after1': 'NN',
#   'pos_after2': 'NNS',
#   'pos_after3': 'VBP',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-DrugBank.d749.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': 'Drug',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': 'Xx'}]
#  non O tags:
# 0
# matchdict
# 0
# predictions length 0
# ...
# model bm3:
# 0.0
#
#
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': True,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': True,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': True,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': False,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'dose-time',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 9,
#   'lenword_before1': '',
#   'lenword_word': 1,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 1,
#   'offsetstart': 0,
#   'pos_after1': 'NP',
#   'pos_after2': 'NNS',
#   'pos_after3': 'IN',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': '[',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': '_'}]
# [{'biotag': 'O',
#   'drugtype': '',
#   'hasDigits_after1': False,
#   'hasDigits_after2': False,
#   'hasDigits_after3': False,
#   'hasDigits_before1': '',
#   'hasDigits_before3': '',
#   'hasDigits_word': False,
#   'hasStrangeChars_after1': False,
#   'hasStrangeChars_before1': '',
#   'hasStrangeChars_before2': '',
#   'hasStrangeChars_word': False,
#   'isLowerCase_after2': True,
#   'isLowerCase_after3': True,
#   'isLowerCase_before1': '',
#   'isLowerCase_before2': '',
#   'isLowerCase_word': False,
#   'isTitleCase_after1': False,
#   'isTitleCase_after2': False,
#   'isTitleCase_after3': False,
#   'isTitleCase_before1': '',
#   'isTitleCase_before3': '',
#   'isTitleCase_word': True,
#   'isUpperCase_after1': False,
#   'isUpperCase_after2': False,
#   'isUpperCase_after3': False,
#   'isUpperCase_before1': '',
#   'isUpperCase_before2': '',
#   'isUpperCase_word': False,
#   'lemma_after1': 'interaction',
#   'lenprefix_after1': 0,
#   'lenprefix_before1': '',
#   'lensuffix_after1': 0,
#   'lensuffix_word': 0,
#   'lenword_after1': 11,
#   'lenword_before1': '',
#   'lenword_word': 4,
#   'moreThan10chars_before1': '',
#   'moreThan10chars_before3': '',
#   'moreThan10chars_word': False,
#   'offsetend': 4,
#   'offsetstart': 0,
#   'pos_after1': 'NN',
#   'pos_after2': 'NNS',
#   'pos_after3': 'VBP',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'prefix_after1': '',
#   'prefix_before1': '',
#   'sentenceid': 'DDI-DrugBank.d749.s0',
#   'suffix_after1': '',
#   'suffix_before1': '',
#   'word': 'Drug',
#   'wordStructure_before2': '',
#   'wordStructure_before3': '',
#   'wordStructure_word': 'Xx'}]
#  non O tags:
# 121
# matchdict
# 64
# [[43, 52, 'estradiol', 'null', 'B'], [62, 74, 'progesterone', 'null', 'B']]
# predictions length 121
# [['DDI-DrugBank.d772.s1', 43, 52, 'estradiol', 'null'], ['DDI-DrugBank.d772.s1', 62, 74, 'progesterone', 'null']]
# DDI-DrugBank.d772.s1|43-52|estradiol|null
# DDI-DrugBank.d772.s1|62-74|progesterone|null
# DDI-DrugBank.d646.s0|79-88|rifaximin|null
# ...
# model bm3:
# 0.3980263157894737

# %%
# generate feature subsets
from CustomFeatures import MyFeatures
from NERmodel import NERmodel
import subprocess
import traceback, sys
import pickle
import yaml
import os

# quick result parsing (fastests matchings found)
NERmodel.batchTestManualAccuracy(
    '../data/batches/debug_batch5.yaml',
    modelfilepath='../data/models/svm-pipeline_20180518151600.pkl')
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# bm3
# ['mod002']
# model bm3:
# accuracy 0.29008746355685133 precision 0.88 recall 0.29 F1 0.44
# accuracy 0.3046757164404223 total 663 cor 202 par 14 mis 447
# accuracy 0.2880116959064328 total 684 cor 197 par 18 mis 469

# %%
# generate feature subsets
from CustomFeatures import MyFeatures
from NERmodel import NERmodel
import subprocess
import traceback, sys
import pickle
import yaml
import os

# best models
NERmodel.batchTraining('../data/batches/debug_bestmodels20180517.yaml')
NERmodel.batchTraining('../data/batches/debug_bestmodels20180517NER.yaml')
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# bm
# ['mod001', 'mod002', 'mod003']
#  non O tags:
# 196
# matchdict
# 85
# [[0, 10, 'Pegaptanib', 'null', 'B']]
# predictions length 196
# [['DDI-DrugBank.d749.s1', 0, 10, 'Pegaptanib', 'null'], ['DDI-DrugBank.d749.s2', 170, 180, 'pegaptanib', 'null']]
# DDI-DrugBank.d749.s1|0-10|Pegaptanib|null
# DDI-DrugBank.d749.s2|170-180|pegaptanib|null
# DDI-DrugBank.d772.s1|43-52|estradiol|null
# ...
# model bm:
# 0.0
#
#
#  non O tags:
# 195
# matchdict
# 85
# [[0, 10, 'Pegaptanib', 'null', 'B']]
# predictions length 195
# [['DDI-DrugBank.d749.s1', 0, 10, 'Pegaptanib', 'null'], ['DDI-DrugBank.d749.s2', 170, 180, 'pegaptanib', 'null']]
# DDI-DrugBank.d749.s1|0-10|Pegaptanib|null
# DDI-DrugBank.d749.s2|170-180|pegaptanib|null
# DDI-DrugBank.d772.s1|43-52|estradiol|null
# ...
# model bm:
# 0.0
#
#
#  non O tags:
# 194
# matchdict
# 85
# [[0, 10, 'Pegaptanib', 'null', 'B']]
# predictions length 194
# [['DDI-DrugBank.d749.s1', 0, 10, 'Pegaptanib', 'null'], ['DDI-DrugBank.d749.s2', 170, 180, 'pegaptanib', 'null']]
# DDI-DrugBank.d749.s1|0-10|Pegaptanib|null
# DDI-DrugBank.d749.s2|170-180|pegaptanib|null
# DDI-DrugBank.d772.s1|43-52|estradiol|null
# ...
# model bm:
# 0.0

# %%
# generate feature subsets
from CustomFeatures import MyFeatures
from NERmodel import NERmodel
import subprocess
import traceback, sys
import pickle
import yaml
import os

# combinations ER
NERmodel.batchTraining('../data/batches/combinationsER20180517.yaml')
# combinations NER
NERmodel.batchTraining('../data/batches/debug_bestmodels_vs_NER.yaml')
#NERmodel.batchTraining('../data/batches/combinationsNER20180517.yaml')
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# combER0517
# ['mod000', 'mod001', 'mod002', 'mod003', 'mod004', 'mod005', 'mod006', 'mod007', 'mod008', 'mod009', 'mod010', 'mod011', 'mod012', 'mod013', 'mod014', 'mod015', 'mod016', 'mod017', 'mod019', 'mod020', 'mod021', 'mod022', 'mod023', 'mod024', 'mod025', 'mod026', 'mod027', 'mod028', 'mod029', 'mod030', 'mod031', 'mod032', 'mod033', 'mod034', 'mod035', 'mod036', 'mod037', 'mod038', 'mod039', 'mod040', 'mod041', 'mod042', 'mod043', 'mod044', 'mod045', 'mod046', 'mod047', 'mod048', 'mod049', 'mod050', 'mod051', 'mod052', 'mod053', 'mod054', 'mod055', 'mod056', 'mod057', 'mod058', 'mod059', 'mod060', 'mod061', 'mod062']
# [{'biotag': 'O',
#   'drugtype': '',
#   'offsetend': 1,
#   'offsetstart': 0,
#   'pos_after1': 'NP',
#   'pos_before1': '',
#   'pos_word': 'Fca',
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'word': '['}]
# [{'biotag': 'O',
#   'drugtype': '',
#   'offsetend': 4,
#   'offsetstart': 0,
#   'pos_after1': 'NN',
#   'pos_before1': '',
#   'pos_word': 'NN',
#   'sentenceid': 'DDI-DrugBank.d749.s0',
#   'word': 'Drug'}]
#  non O tags:
# 276
# matchdict
# 110
# [[54, 61, 'Macugen', 'null', 'B']]
# predictions length 276
# [['DDI-DrugBank.d749.s0', 54, 61, 'Macugen', 'null'], ['DDI-DrugBank.d749.s1', 0, 10, 'Pegaptanib', 'null']]
# DDI-DrugBank.d749.s0|54-61|Macugen|null
# DDI-DrugBank.d749.s1|0-10|Pegaptanib|null
# DDI-DrugBank.d749.s2|62-69|Macugen|null
# ...
# model combER0517:
# 0.9078947368421053
#
#
# [{'biotag': 'O',
#   'drugtype': '',
#   'offsetend': 1,
#   'offsetstart': 0,
#   'pos_after1': 'NP',
#   'pos_after2': 'NNS',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_word': 'Fca',
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'word': '['}]
# [{'biotag': 'O',
#   'drugtype': '',
#   'offsetend': 4,
#   'offsetstart': 0,
#   'pos_after1': 'NN',
#   'pos_after2': 'NNS',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_word': 'NN',
#   'sentenceid': 'DDI-DrugBank.d749.s0',
#   'word': 'Drug'}]
#  non O tags:
# 276
# matchdict
# 110
# [[54, 61, 'Macugen', 'null', 'B']]
# predictions length 276
# [['DDI-DrugBank.d749.s0', 54, 61, 'Macugen', 'null'], ['DDI-DrugBank.d749.s1', 0, 10, 'Pegaptanib', 'null']]
# DDI-DrugBank.d749.s0|54-61|Macugen|null
# DDI-DrugBank.d749.s1|0-10|Pegaptanib|null
# DDI-DrugBank.d749.s2|62-69|Macugen|null
# ...
# model combER0517:
# 0.9078947368421053
#
#
# [{'biotag': 'O',
#   'drugtype': '',
#   'offsetend': 1,
#   'offsetstart': 0,
#   'pos_after1': 'NP',
#   'pos_after2': 'NNS',
#   'pos_after3': 'IN',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'pos_word': 'Fca',
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'word': '['}]
# [{'biotag': 'O',
#   'drugtype': '',
#   'offsetend': 4,
#   'offsetstart': 0,
#   'pos_after1': 'NN',
#   'pos_after2': 'NNS',
#   'pos_after3': 'VBP',
#   'pos_before1': '',
#   'pos_before2': '',
#   'pos_before3': '',
#   'pos_word': 'NN',
#   'sentenceid': 'DDI-DrugBank.d749.s0',
#   'word': 'Drug'}]
#  non O tags:
# 274
# matchdict
# 110
# [[54, 61, 'Macugen', 'null', 'B']]
# predictions length 274
# [['DDI-DrugBank.d749.s0', 54, 61, 'Macugen', 'null'], ['DDI-DrugBank.d749.s1', 0, 10, 'Pegaptanib', 'null']]
# DDI-DrugBank.d749.s0|54-61|Macugen|null
# DDI-DrugBank.d749.s1|0-10|Pegaptanib|null
# DDI-DrugBank.d749.s2|62-69|Macugen|null
# ...
# model combER0517:
# 0.9013157894736842
#
#
# [{'biotag': 'O',
#   'drugtype': '',
#   'lemma_after1': 'dose-time',
#   'lemma_before1': '',
#   'lemma_word': '[',
#   'offsetend': 1,
#   'offsetstart': 0,
#   'sentenceid': 'DDI-MedLine.d134.s0',
#   'word': '['}]

# %%
# generate feature subsets
from CustomFeatures import MyFeatures
from NERmodel import NERmodel
import subprocess
import traceback, sys
import pickle
import yaml
import os


NERmodel.batchTraining('../data/batches/debug_bestmodels_vs_NER.yaml')
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# bm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-fb9cabed8eeb> in <module>()
#       9
#      10
# ---> 11 NERmodel.batchTraining('../data/batches/debug_bestmodels_vs_NER.yaml')
#      12
#      13
#
# /media/disk/home/pau/Projectes/AHLT-mai/src/NERmodel.py in batchTraining(configfile)
#     332         for modelname,params in conf["models"].items():
#     333             try:
# --> 334                 mf = MyFeatures(params=params)
#     335                 fs.append((mf,modelname,params["modeltype"],params))
#     336                 NERmodel.writeConf(conf,modelname,"status", "doing" )
#
# /media/disk/home/pau/Projectes/AHLT-mai/src/CustomFeatures.py in __init__(self, params)
#       9
#      10     def __init__(self, params=None):
# ---> 11         self.f = FreelingFeatures.FreelingFeatures()
#      12         self.features_list = [
#      13             self.isTitleCase,
#
# /media/disk/home/pau/Projectes/AHLT-mai/src/FreelingFeatures.py in __init__(self)
#      28                                   True); # ProbabilityAssignment
#      29         # create tagger
# ---> 30         self.tagger = freeling.hmm_tagger(self.lpath+"tagger.dat",True,2)
#      31
#      32
#
# ~/anaconda3/envs/ahltmai/lib/python3.6/pyfreeling.py in __init__(self, arg2, arg3, arg4, kb)
#    5844
#    5845     def __init__(self, arg2: 'std::wstring const &', arg3: 'bool', arg4: 'unsigned int', kb: 'unsigned int'=1):
# -> 5846         this = _pyfreeling.new_hmm_tagger(arg2, arg3, arg4, kb)
#    5847         try:
#    5848             self.this.append(this)
#
# KeyboardInterrupt:
