# %%
# repeating the same with a class
from NERmodel import NERmodel

model = NERmodel()
#model.trainFeatureExtraction("../data/LaboCase/Train", limit=200)
model.trainFeatureExtraction("../data/LaboCase/Train")
model.saveTrainingFeatures("../data/models/data-train2.json")
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from NERmodel import NERmodel
model = NERmodel()
model.loadTrainingFeatures("../data/models/data-train2.json")

model.newModelPipeline()
filepath = model.saveModelPipeline()
print(filepath)
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# ../data/models/svm-pipeline_201805092025.pkl

# %%
from NERmodel import NERmodel
model = NERmodel()
model.testFeatureExtraction("../data/LaboCase/Test", limit=100)
model.saveTestFeatures('../data/models/data-test2.json')
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from NERmodel import NERmodel
model = NERmodel()
model.loadModelPipeline('../data/models/svm-pipeline_201805092025.pkl')
model.loadTestFeatures('../data/models/data-test2.json')
model.predict()
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
model.parsePredictionOutput('../data/models/task9.1_AHLT_2.txt')

with open('../data/models/task9.1_AHLT_2.txt','r') as f:
    #print(f.read())
    for line in f.readlines()[:3]:
        print(line)
        
model.parsePredictionOutput()
        results_files[i] = '../data/models/multitrain-'+str(i)+'-output.csv'
        evaluation_files[i] = model.autoEvaluation()
# Out:
# DDI-MedLine.d175.s0|0|71|Unrecognized|
# DDI-MedLine.d175.s1|0|103|Colchicine|B
# DDI-MedLine.d175.s2|0|81|It|
# DDI-MedLine.d175.s3|0|384|We|
# DDI-MedLine.d175.s4|0|115|We|
# DDI-MedLine.d175.s5|0|129|Subjects|
# DDI-MedLine.d175.s6|0|65|We|
# DDI-MedLine.d175.s7|0|230|An|
# DDI-MedLine.d175.s8|0|97|Thirty-seven|
# DDI-MedLine.d175.s9|0|86|Toxicity|
# DDI-MedLine.d175.s10|0|129|A|
# DDI-MedLine.d175.s11|0|191|Colchicine|B
# DDI-MedLine.d175.s12|0|149|Seventeen|
# DDI-MedLine.d175.s13|0|106|Colchicine|B
# DDI-MedLine.d175.s14|0|93|Inappropriate|
# DDI-MedLine.d157.s0|0|70|Tradition|
# DDI-MedLine.d157.s1|0|172|This|
# DDI-MedLine.d157.s2|0|176|Kava|
# DDI-MedLine.d157.s3|0|184|This|
# DDI-MedLine.d157.s4|0|176|Cultural|
# DDI-MedLine.d157.s5|0|175|Though|
# DDI-MedLine.d157.s6|0|186|This|
# DDI-MedLine.d202.s0|0|76|Flow|
# DDI-MedLine.d202.s1|0|203|Conventional|
# DDI-MedLine.d202.s2|0|144|Since|
# DDI-MedLine.d202.s3|0|239|In|
# DDI-MedLine.d202.s4|0|203|Therefore|
# DDI-MedLine.d202.s5|0|177|Flow|
# DDI-MedLine.d202.s6|0|190|A|
# DDI-MedLine.d202.s7|0|132|By|
# DDI-MedLine.d202.s8|0|241|Furthermore|
# DDI-MedLine.d202.s9|0|188|Such|
# DDI-MedLine.d228.s0|0|65|Pulmonary|
# DDI-MedLine.d228.s1|0|157|Pulmonary|
# DDI-MedLine.d228.s2|0|181|This|
# DDI-MedLine.d228.s3|0|201|Although|
# DDI-MedLine.d205.s0|0|70|Tuberculosis|
# DDI-MedLine.d205.s1|0|63|Globally|
# DDI-MedLine.d205.s2|0|156|The|
# DDI-MedLine.d205.s3|0|255|Despite|
# DDI-MedLine.d205.s4|0|275|Many|
# DDI-MedLine.d205.s5|0|231|Due|
# DDI-MedLine.d205.s6|0|81|We|
# DDI-MedLine.d205.s7|0|174|Recent|
# DDI-MedLine.d178.s0|0|83|[|
# DDI-MedLine.d178.s1|0|74|Ticagrelor|B
# DDI-MedLine.d178.s2|0|178|In|
# DDI-MedLine.d156.s0|0|114|ABC|
# DDI-MedLine.d156.s1|0|150|Some|
# DDI-MedLine.d156.s2|0|92|Compounds|
# DDI-MedLine.d156.s3|0|126|Of|
# DDI-MedLine.d156.s4|0|99|In|
# DDI-MedLine.d156.s5|0|124|The|
# DDI-MedLine.d156.s6|0|106|There|
# DDI-MedLine.d156.s7|0|127|Co-administration|
# DDI-MedLine.d156.s8|0|77|however|
# DDI-MedLine.d156.s9|0|121|The|
# DDI-MedLine.d144.s0|0|124|Older|
# DDI-MedLine.d144.s1|0|134|Older|
# DDI-MedLine.d144.s2|0|166|Personal|
# DDI-MedLine.d144.s3|0|116|Optimizing|
# DDI-MedLine.d203.s0|0|110|Potential|
# DDI-MedLine.d203.s1|0|216|To|
# DDI-MedLine.d203.s2|0|19|Longitudinal|
# DDI-MedLine.d203.s3|0|33|One|
# DDI-MedLine.d203.s4|0|147|Three|
# DDI-MedLine.d203.s5|0|268|Prevalence|
# DDI-MedLine.d203.s6|0|89|Selective|B
# DDI-MedLine.d203.s7|0|109|Of|
# DDI-MedLine.d203.s8|0|173|Of|
# DDI-MedLine.d203.s9|0|110|Of|
# DDI-MedLine.d203.s10|0|117|only|
# DDI-MedLine.d203.s11|0|70|Overall|
# DDI-MedLine.d203.s12|0|295|The|
# DDI-MedLine.d203.s13|0|205|Having|
# DDI-MedLine.d203.s14|0|89|Potential|
# DDI-MedLine.d203.s15|0|22|veteran|
# DDI-MedLine.d203.s16|0|119|Future|
# DDI-MedLine.d158.s0|0|140|Combining|
# DDI-MedLine.d158.s1|0|198|The|
# DDI-MedLine.d158.s2|0|103|mRPCs|
# DDI-MedLine.d158.s3|0|292|All|
# DDI-MedLine.d158.s4|0|85|Cell|
# DDI-MedLine.d158.s5|0|111|Immunohistochemistry|
# DDI-MedLine.d158.s6|0|155|Our|
# DDI-MedLine.d158.s7|0|85|Chondroitinase|
# DDI-MedLine.d158.s8|0|48|Only|
# DDI-MedLine.d158.s9|0|159|More|
# DDI-MedLine.d158.s10|0|142|The|
# DDI-MedLine.d173.s0|0|50|[|
# DDI-MedLine.d173.s1|0|182|Tuberculosis|
# DDI-MedLine.d173.s2|0|139|Currently|
# DDI-MedLine.d173.s3|0|99|Drug|
# DDI-MedLine.d173.s4|0|146|New|
# DDI-MedLine.d232.s0|0|84|Stroke|
# DDI-MedLine.d232.s1|0|104|Prevention|
# DDI-MedLine.d232.s2|0|96|However|
# DDI-MedLine.d232.s3|0|138|Risk|
# DDI-MedLine.d232.s4|0|173|According|
# DDI-MedLine.d232.s5|0|116|Despite|

# %%
# repeating the same with a class
from NERmodel import NERmodel

model = NERmodel()
#model.trainFeatureExtraction("../data/LaboCase/Train", limit=2)
model.trainFeatureExtraction("../data/LaboCase/Train")
model.saveTrainingFeatures("../data/models/data-train3.json")
model.traindata.data[:2]
# Out:
# /home/pau/anaconda3/envs/ahltmai/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# [{'Error': False,
#   'bioerrors': 6,
#   'entities': [{'charOffset': '50-67',
#     'id': 'DDI-MedLine.d134.s0.e0',
#     'text': 'radiopertechnetate',
#     'type': 'drug'},
#    {'charOffset': '72-89',
#     'id': 'DDI-MedLine.d134.s0.e1',
#     'text': 'sodium perchlorate',
#     'type': 'drug_n'},
#    {'charOffset': '169-186',
#     'id': 'DDI-MedLine.d134.s0.e2',
#     'text': 'sodium perchlorate',
#     'type': 'drug_n'},
#    {'charOffset': '266-283',
#     'id': 'DDI-MedLine.d134.s0.e3',
#     'text': 'radiopertechnetate',
#     'type': 'drug'}],
#   'errors': [],
#   'features': [('[',
#     '[',
#     'Fca',
#     'DDI-MedLine.d134.s0',
#     0,
#     1,
#     'O',
#     '',
#     False,
#     False,
#     False,
#     False,
#     True,
#     False,
#     0,
#     0,
#     1,
#     '',
#     'NN',
#     '',
#     'NNS',
#     ''),
#    ('Dose-time',
#     'dose-time',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     1,
#     10,
#     'O',
#     '',
#     True,
#     False,
#     False,
#     False,
#     True,
#     False,
#     0,
#     0,
#     9,
#     'Fca',
#     'NNS',
#     '',
#     'IN',
#     ''),
#    ('effects',
#     'effect',
#     'NNS',
#     'DDI-MedLine.d134.s0',
#     11,
#     18,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     1,
#     7,
#     'NN',
#     'IN',
#     'Fca',
#     'JJ',
#     ''),
#    ('of',
#     'of',
#     'IN',
#     'DDI-MedLine.d134.s0',
#     19,
#     21,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NNS',
#     'JJ',
#     'NN',
#     'NN',
#     'Fca'),
#    ('competitive',
#     'competitive',
#     'JJ',
#     'DDI-MedLine.d134.s0',
#     22,
#     33,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     11,
#     'IN',
#     'NN',
#     'NNS',
#     'IN',
#     'NN'),
#    ('displacement',
#     'displacement',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     34,
#     46,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     12,
#     'JJ',
#     'IN',
#     'IN',
#     'NN',
#     'NNS'),
#    ('of',
#     'of',
#     'IN',
#     'DDI-MedLine.d134.s0',
#     47,
#     49,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'NN',
#     'JJ',
#     'IN',
#     'IN'),
#    ('radiopertechnetate',
#     'radiopertechnetate',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     50,
#     68,
#     'O',
#     'B',
#     'drug',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     18,
#     'IN',
#     'IN',
#     'NN',
#     'NN',
#     'JJ'),
#    ('by',
#     'by',
#     'IN',
#     'DDI-MedLine.d134.s0',
#     69,
#     71,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'NN',
#     'IN',
#     'NN',
#     'NN'),
#    ('sodium',
#     'sodium',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     72,
#     78,
#     'O',
#     'B',
#     'drug_n',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     6,
#     'IN',
#     'NN',
#     'NN',
#     'VBG',
#     'IN'),
#    ('perchlorate',
#     'perchlorate',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     79,
#     90,
#     'O',
#     'I',
#     'drug_n',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     11,
#     'NN',
#     'VBG',
#     'IN',
#     'JJ',
#     'NN'),
#    ('following',
#     'follow',
#     'VBG',
#     'DDI-MedLine.d134.s0',
#     91,
#     100,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     3,
#     9,
#     'NN',
#     'JJ',
#     'NN',
#     'CC',
#     'IN'),
#    ('oral',
#     'oral',
#     'JJ',
#     'DDI-MedLine.d134.s0',
#     101,
#     105,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     4,
#     'VBG',
#     'CC',
#     'NN',
#     'JJ',
#     'NN'),
#    ('and',
#     'and',
#     'CC',
#     'DDI-MedLine.d134.s0',
#     106,
#     109,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     3,
#     'JJ',
#     'JJ',
#     'VBG',
#     'NN',
#     'NN'),
#    ('intravenous',
#     'intravenous',
#     'JJ',
#     'DDI-MedLine.d134.s0',
#     110,
#     121,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     11,
#     'CC',
#     'NN',
#     'JJ',
#     'Fct',
#     'VBG'),
#    ('administration',
#     'administration',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     122,
#     136,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     14,
#     'JJ',
#     'Fct',
#     'CC',
#     'DT',
#     'JJ'),
#    (']',
#     ']',
#     'Fct',
#     'DDI-MedLine.d134.s0',
#     136,
#     137,
#     'O',
#     '',
#     False,
#     False,
#     False,
#     False,
#     True,
#     False,
#     0,
#     0,
#     1,
#     'NN',
#     'DT',
#     'JJ',
#     'NN',
#     'CC'),
#    ('The',
#     'the',
#     'DT',
#     'DDI-MedLine.d134.s0',
#     138,
#     141,
#     'O',
#     '',
#     True,
#     False,
#     False,
#     False,
#     False,
#     False,
#     0,
#     0,
#     3,
#     'Fct',
#     'NN',
#     'NN',
#     'IN',
#     'JJ'),
#    ('effect',
#     'effect',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     142,
#     148,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     6,
#     'DT',
#     'IN',
#     'Fct',
#     'JJ',
#     'NN'),
#    ('of',
#     'of',
#     'IN',
#     'DDI-MedLine.d134.s0',
#     149,
#     151,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'JJ',
#     'DT',
#     'NNS',
#     'Fct'),
#    ('various',
#     'various',
#     'JJ',
#     'DDI-MedLine.d134.s0',
#     152,
#     159,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     7,
#     'IN',
#     'NNS',
#     'NN',
#     'IN',
#     'DT'),
#    ('doses',
#     'dose',
#     'NNS',
#     'DDI-MedLine.d134.s0',
#     160,
#     165,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     1,
#     5,
#     'JJ',
#     'IN',
#     'IN',
#     'NN',
#     'NN'),
#    ('of',
#     'of',
#     'IN',
#     'DDI-MedLine.d134.s0',
#     166,
#     168,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NNS',
#     'NN',
#     'JJ',
#     'NN',
#     'IN'),
#    ('sodium',
#     'sodium',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     169,
#     175,
#     'O',
#     'B',
#     'drug_n',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     6,
#     'IN',
#     'NN',
#     'NNS',
#     'IN',
#     'JJ'),
#    ('perchlorate',
#     'perchlorate',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     176,
#     187,
#     'O',
#     'I',
#     'drug_n',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     11,
#     'NN',
#     'IN',
#     'IN',
#     'DT',
#     'NNS'),
#    ('in',
#     'in',
#     'IN',
#     'DDI-MedLine.d134.s0',
#     188,
#     190,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'DT',
#     'NN',
#     'NN',
#     'IN'),
#    ('several',
#     'several',
#     'DT',
#     'DDI-MedLine.d134.s0',
#     191,
#     198,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     7,
#     'IN',
#     'NN',
#     'NN',
#     'NNS',
#     'NN'),
#    ('dose',
#     'dose',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     199,
#     203,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     4,
#     'DT',
#     'NNS',
#     'IN',
#     'IN',
#     'NN'),
#    ('fractions',
#     'fraction',
#     'NNS',
#     'DDI-MedLine.d134.s0',
#     204,
#     213,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     1,
#     9,
#     'NN',
#     'IN',
#     'DT',
#     'DT',
#     'IN'),
#    ('on',
#     'on',
#     'IN',
#     'DDI-MedLine.d134.s0',
#     214,
#     216,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NNS',
#     'DT',
#     'NN',
#     'NN',
#     'DT'),
#    ('the',
#     'the',
#     'DT',
#     'DDI-MedLine.d134.s0',
#     217,
#     220,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     3,
#     'IN',
#     'NN',
#     'NNS',
#     'CC',
#     'NN'),
#    ('extent',
#     'extent',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     221,
#     227,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     6,
#     'DT',
#     'CC',
#     'IN',
#     'DT',
#     'NNS'),
#    ('and',
#     'and',
#     'CC',
#     'DDI-MedLine.d134.s0',
#     228,
#     231,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     3,
#     'NN',
#     'DT',
#     'DT',
#     'NN',
#     'IN'),
#    ('the',
#     'the',
#     'DT',
#     'DDI-MedLine.d134.s0',
#     232,
#     235,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     3,
#     'CC',
#     'NN',
#     'NN',
#     'NN',
#     'DT'),
#    ('time',
#     'time',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     236,
#     240,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     4,
#     'DT',
#     'NN',
#     'CC',
#     'IN',
#     'NN'),
#    ('scale',
#     'scale',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     241,
#     246,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     5,
#     'NN',
#     'IN',
#     'DT',
#     'NN',
#     'CC'),
#    ('of',
#     'of',
#     'IN',
#     'DDI-MedLine.d134.s0',
#     247,
#     249,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'NN',
#     'NN',
#     'IN',
#     'DT'),
#    ('displacement',
#     'displacement',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     250,
#     262,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     12,
#     'IN',
#     'IN',
#     'NN',
#     'NN',
#     'NN'),
#    ('of',
#     'of',
#     'IN',
#     'DDI-MedLine.d134.s0',
#     263,
#     265,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'NN',
#     'IN',
#     'Fc',
#     'NN'),
#    ('radiopertechnetate',
#     'radiopertechnetate',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     266,
#     284,
#     'O',
#     'B',
#     'drug',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     18,
#     'IN',
#     'Fc',
#     'NN',
#     'IN',
#     'IN'),
#    (',',
#     ',',
#     'Fc',
#     'DDI-MedLine.d134.s0',
#     284,
#     285,
#     'O',
#     '',
#     False,
#     False,
#     False,
#     False,
#     True,
#     False,
#     0,
#     0,
#     1,
#     'NN',
#     'IN',
#     'IN',
#     'NN',
#     'NN'),
#    ('in',
#     'in',
#     'IN',
#     'DDI-MedLine.d134.s0',
#     286,
#     288,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'Fc',
#     'NN',
#     'NN',
#     'IN',
#     'IN'),
#    ('dependence',
#     'dependence',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     289,
#     299,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     10,
#     'IN',
#     'IN',
#     'Fc',
#     'NN',
#     'NN'),
#    ('on',
#     'on',
#     'IN',
#     'DDI-MedLine.d134.s0',
#     300,
#     302,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'NN',
#     'IN',
#     'NN',
#     'Fc'),
#    ('application',
#     'application',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     303,
#     314,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     11,
#     'IN',
#     'NN',
#     'NN',
#     'Fc',
#     'IN'),
#    ('mode',
#     'mode',
#     'NN',
#     'DDI-MedLine.d134.s0',
#     315,
#     319,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     4,
#     'NN',
#     'Fc',
#     'IN',
#     'VBD',
#     'NN'),
#    (',',
#     ',',
#     'Fc',
#     'DDI-MedLine.d134.s0',
#     319,
#     320,
#     'O',
#     '',
#     False,
#     False,
#     False,
#     False,
#     True,
#     False,
#     0,
#     0,
#     1,
#     'NN',
#     'VBD',
#     'NN',
#     'VBN',
#     'IN'),
#    ('was',
#     'be',
#     'VBD',
#     'DDI-MedLine.d134.s0',
#     321,
#     324,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     3,
#     'Fc',
#     'VBN',
#     'NN',
#     'Fp',
#     'NN'),
#    ('studied',
#     'study',
#     'VBN',
#     'DDI-MedLine.d134.s0',
#     325,
#     332,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     7,
#     'VBD',
#     'Fp',
#     'Fc',
#     '',
#     'NN'),
#    ('.',
#     '.',
#     'Fp',
#     'DDI-MedLine.d134.s0',
#     332,
#     333,
#     'O',
#     '',
#     False,
#     False,
#     False,
#     False,
#     True,
#     False,
#     0,
#     0,
#     1,
#     'VBN',
#     '',
#     'VBD',
#     '',
#     'Fc')],
#   'id': 'DDI-MedLine.d134.s0',
#   'offsets': [(50, 68, ['radiopertechnetate'], 'drug'),
#    (72, 90, ['sodium', 'perchlorate'], 'drug_n'),
#    (169, 187, ['sodium', 'perchlorate'], 'drug_n'),
#    (266, 284, ['radiopertechnetate'], 'drug')],
#   'pairs': [{'ddi': 'false',
#     'e1': 'DDI-MedLine.d134.s0.e0',
#     'e2': 'DDI-MedLine.d134.s0.e1',
#     'id': 'DDI-MedLine.d134.s0.p0'},
#    {'ddi': 'false',
#     'e1': 'DDI-MedLine.d134.s0.e0',
#     'e2': 'DDI-MedLine.d134.s0.e2',
#     'id': 'DDI-MedLine.d134.s0.p1'},
#    {'ddi': 'false',
#     'e1': 'DDI-MedLine.d134.s0.e0',
#     'e2': 'DDI-MedLine.d134.s0.e3',
#     'id': 'DDI-MedLine.d134.s0.p2'},
#    {'ddi': 'false',
#     'e1': 'DDI-MedLine.d134.s0.e1',
#     'e2': 'DDI-MedLine.d134.s0.e2',
#     'id': 'DDI-MedLine.d134.s0.p3'},
#    {'ddi': 'false',
#     'e1': 'DDI-MedLine.d134.s0.e1',
#     'e2': 'DDI-MedLine.d134.s0.e3',
#     'id': 'DDI-MedLine.d134.s0.p4'},
#    {'ddi': 'false',
#     'e1': 'DDI-MedLine.d134.s0.e2',
#     'e2': 'DDI-MedLine.d134.s0.e3',
#     'id': 'DDI-MedLine.d134.s0.p5'}],
#   'text': '[Dose-time effects of competitive displacement of radiopertechnetate by sodium perchlorate following oral and intravenous administration]\nThe effect of various doses of sodium perchlorate in several dose fractions on the extent and the time scale of displacement of radiopertechnetate, in dependence on application mode, was studied. ',
#   'token_entities': []},
#  {'Error': False,
#   'bioerrors': 3,
#   'entities': [{'charOffset': '29-39',
#     'id': 'DDI-MedLine.d134.s1.e0',
#     'text': 'perchlorate',
#     'type': 'drug_n'},
#    {'charOffset': '116-128',
#     'id': 'DDI-MedLine.d134.s1.e1',
#     'text': 'pertechnetate',
#     'type': 'drug'},
#    {'charOffset': '237-254',
#     'id': 'DDI-MedLine.d134.s1.e2',
#     'text': 'radiopertechnetate',
#     'type': 'drug'}],
#   'errors': [],
#   'features': [('An',
#     'a',
#     'DT',
#     'DDI-MedLine.d134.s1',
#     0,
#     2,
#     'O',
#     '',
#     True,
#     False,
#     False,
#     False,
#     False,
#     False,
#     0,
#     1,
#     2,
#     '',
#     'JJ',
#     '',
#     'NN',
#     ''),
#    ('intravenous',
#     'intravenous',
#     'JJ',
#     'DDI-MedLine.d134.s1',
#     3,
#     14,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     11,
#     'DT',
#     'NN',
#     '',
#     'IN',
#     ''),
#    ('dose',
#     'dose',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     15,
#     19,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     4,
#     'JJ',
#     'IN',
#     'DT',
#     'NN',
#     ''),
#    ('of',
#     'of',
#     'IN',
#     'DDI-MedLine.d134.s1',
#     20,
#     22,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'NN',
#     'JJ',
#     'VBG',
#     'DT'),
#    ('50',
#     '50',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     23,
#     25,
#     'O',
#     '',
#     False,
#     False,
#     False,
#     True,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'IN',
#     'VBG',
#     'NN',
#     'NN',
#     'JJ'),
#    ('mg',
#     'mg',
#     'VBG',
#     'DDI-MedLine.d134.s1',
#     26,
#     28,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'NN',
#     'IN',
#     'VBD',
#     'NN'),
#    ('perchlorate',
#     'perchlorate',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     29,
#     40,
#     'O',
#     'B',
#     'drug_n',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     11,
#     'VBG',
#     'VBD',
#     'NN',
#     'IN',
#     'IN'),
#    ('was',
#     'be',
#     'VBD',
#     'DDI-MedLine.d134.s1',
#     41,
#     44,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     3,
#     'NN',
#     'IN',
#     'VBG',
#     'NN',
#     'NN'),
#    ('in',
#     'in',
#     'IN',
#     'DDI-MedLine.d134.s1',
#     45,
#     47,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'VBD',
#     'NN',
#     'NN',
#     'IN',
#     'VBG'),
#    ('respect',
#     'respect',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     48,
#     55,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     7,
#     'IN',
#     'IN',
#     'VBD',
#     'JJ',
#     'NN'),
#    ('of',
#     'of',
#     'IN',
#     'DDI-MedLine.d134.s1',
#     56,
#     58,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'JJ',
#     'IN',
#     'NN',
#     'VBD'),
#    ('competitive',
#     'competitive',
#     'JJ',
#     'DDI-MedLine.d134.s1',
#     59,
#     70,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     11,
#     'IN',
#     'NN',
#     'NN',
#     'IN',
#     'IN'),
#    ('suppression',
#     'suppression',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     71,
#     82,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     11,
#     'JJ',
#     'IN',
#     'IN',
#     'NNS',
#     'NN'),
#    ('of',
#     'of',
#     'IN',
#     'DDI-MedLine.d134.s1',
#     83,
#     85,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'NNS',
#     'JJ',
#     'RB',
#     'IN'),
#    ('organs',
#     'organ',
#     'NNS',
#     'DDI-MedLine.d134.s1',
#     86,
#     92,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     1,
#     6,
#     'IN',
#     'RB',
#     'NN',
#     'VBG',
#     'JJ'),
#    ('actively',
#     'actively',
#     'RB',
#     'DDI-MedLine.d134.s1',
#     93,
#     101,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     8,
#     'NNS',
#     'VBG',
#     'IN',
#     'NN',
#     'NN'),
#    ('concentrating',
#     'concentrate',
#     'VBG',
#     'DDI-MedLine.d134.s1',
#     102,
#     115,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     13,
#     'RB',
#     'NN',
#     'NNS',
#     'IN',
#     'IN'),
#    ('pertechnetate',
#     'pertechnetate',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     116,
#     129,
#     'O',
#     'B',
#     'drug',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     13,
#     'VBG',
#     'IN',
#     'RB',
#     'JJ',
#     'NNS'),
#    ('as',
#     'as',
#     'IN',
#     'DDI-MedLine.d134.s1',
#     130,
#     132,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'JJ',
#     'VBG',
#     'IN',
#     'RB'),
#    ('effective',
#     'effective',
#     'JJ',
#     'DDI-MedLine.d134.s1',
#     133,
#     142,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     9,
#     'IN',
#     'IN',
#     'NN',
#     'JJ',
#     'VBG'),
#    ('as',
#     'as',
#     'IN',
#     'DDI-MedLine.d134.s1',
#     143,
#     145,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'JJ',
#     'JJ',
#     'IN',
#     'NN',
#     'NN'),
#    ('intravenous',
#     'intravenous',
#     'JJ',
#     'DDI-MedLine.d134.s1',
#     146,
#     157,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     11,
#     'IN',
#     'NN',
#     'JJ',
#     'VBG',
#     'IN'),
#    ('1000',
#     '1000',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     158,
#     162,
#     'O',
#     '',
#     False,
#     False,
#     False,
#     True,
#     False,
#     False,
#     0,
#     0,
#     4,
#     'JJ',
#     'VBG',
#     'IN',
#     'NN',
#     'JJ'),
#    ('mg',
#     'mg',
#     'VBG',
#     'DDI-MedLine.d134.s1',
#     163,
#     165,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'NN',
#     'JJ',
#     'Fg',
#     'IN'),
#    ('ClO-4',
#     'clo-4',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     166,
#     171,
#     'O',
#     '',
#     True,
#     False,
#     False,
#     False,
#     True,
#     False,
#     0,
#     0,
#     5,
#     'VBG',
#     'Fg',
#     'NN',
#     'RB',
#     'JJ'),
#    ('-',
#     '-',
#     'Fg',
#     'DDI-MedLine.d134.s1',
#     171,
#     172,
#     'O',
#     '',
#     False,
#     False,
#     False,
#     False,
#     True,
#     False,
#     0,
#     0,
#     1,
#     'NN',
#     'RB',
#     'VBG',
#     'CC',
#     'NN'),
#    ('simultaneously',
#     'simultaneously',
#     'RB',
#     'DDI-MedLine.d134.s1',
#     173,
#     187,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     14,
#     'Fg',
#     'CC',
#     'NN',
#     'NN',
#     'VBG'),
#    ('or',
#     'or',
#     'CC',
#     'DDI-MedLine.d134.s1',
#     188,
#     190,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'RB',
#     'NN',
#     'Fg',
#     'VBG',
#     'NN'),
#    ('1000',
#     '1000',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     191,
#     195,
#     'O',
#     '',
#     False,
#     False,
#     False,
#     True,
#     False,
#     False,
#     0,
#     0,
#     4,
#     'CC',
#     'VBG',
#     'RB',
#     'RB',
#     'Fg'),
#    ('mg',
#     'mg',
#     'VBG',
#     'DDI-MedLine.d134.s1',
#     196,
#     198,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'RB',
#     'CC',
#     'NN',
#     'RB'),
#    ('orally',
#     'orally',
#     'RB',
#     'DDI-MedLine.d134.s1',
#     199,
#     205,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     6,
#     'VBG',
#     'NN',
#     'NN',
#     'NN',
#     'CC'),
#    ('30',
#     '30',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     206,
#     208,
#     'O',
#     '',
#     False,
#     False,
#     False,
#     True,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'RB',
#     'NN',
#     'VBG',
#     'IN',
#     'NN'),
#    ('min',
#     'min',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     209,
#     212,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     3,
#     'NN',
#     'IN',
#     'RB',
#     'DT',
#     'VBG'),
#    ('before',
#     'before',
#     'IN',
#     'DDI-MedLine.d134.s1',
#     213,
#     219,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     6,
#     'NN',
#     'DT',
#     'NN',
#     'NN',
#     'RB'),
#    ('the',
#     'the',
#     'DT',
#     'DDI-MedLine.d134.s1',
#     220,
#     223,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     3,
#     'IN',
#     'NN',
#     'NN',
#     'IN',
#     'NN'),
#    ('injection',
#     'injection',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     224,
#     233,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     9,
#     'DT',
#     'IN',
#     'IN',
#     'NN',
#     'NN'),
#    ('of',
#     'of',
#     'IN',
#     'DDI-MedLine.d134.s1',
#     234,
#     236,
#     'O',
#     '',
#     False,
#     False,
#     True,
#     False,
#     False,
#     False,
#     0,
#     0,
#     2,
#     'NN',
#     'NN',
#     'DT',
#     'Fp',
#     'IN'),
#    ('radiopertechnetate',
#     'radiopertechnetate',
#     'NN',
#     'DDI-MedLine.d134.s1',
#     237,
#     255,
#     'O',
#     'B',
#     'drug',
#     False,
#     False,
#     True,
#     False,
#     False,
#     True,
#     0,
#     0,
#     18,
#     'IN',
#     'Fp',
#     'NN',
#     '',
#     'DT'),
#    ('.',
#     '.',
#     'Fp',
#     'DDI-MedLine.d134.s1',
#     255,
#     256,
#     'O',
#     '',
#     False,
#     False,
#     False,
#     False,
#     True,
#     False,
#     0,
#     0,
#     1,
#     'NN',
#     '',
#     'IN',
#     '',
#     'NN')],
#   'id': 'DDI-MedLine.d134.s1',
#   'offsets': [(29, 40, ['perchlorate'], 'drug_n'),
#    (116, 129, ['pertechnetate'], 'drug'),
#    (237, 255, ['radiopertechnetate'], 'drug')],
#   'pairs': [{'ddi': 'false',
#     'e1': 'DDI-MedLine.d134.s1.e0',
#     'e2': 'DDI-MedLine.d134.s1.e1',
#     'id': 'DDI-MedLine.d134.s1.p0'},
#    {'ddi': 'false',
#     'e1': 'DDI-MedLine.d134.s1.e0',
#     'e2': 'DDI-MedLine.d134.s1.e2',
#     'id': 'DDI-MedLine.d134.s1.p1'},
#    {'ddi': 'false',
#     'e1': 'DDI-MedLine.d134.s1.e1',
#     'e2': 'DDI-MedLine.d134.s1.e2',
#     'id': 'DDI-MedLine.d134.s1.p2'}],
#   'text': 'An intravenous dose of 50 mg perchlorate was in respect of competitive suppression of organs actively concentrating pertechnetate as effective as intravenous 1000 mg ClO-4- simultaneously or 1000 mg orally 30 min before the injection of radiopertechnetate. ',
#   'token_entities': []}]
